# %%
###############################################################################
##################### CODE FOR THE BCCP WEB SCRAPING COURSE ###################
############################## JUNE 24 TO 26, 2019 ############################
############################ SECTION ON HTML PARSING ##########################
###############################################################################

### Where to save file?
savefile = \
   "C:/Users/kevin/Documents/GitHub/web_scraping_course/results/bccp_events.csv"

###############################################################################
############################## LOAD NEEDED MODULES ############################
###############################################################################

# Show everything in Jupyter notebooks (not just last result)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# requests to load URLs
import requests
# BeautifulSoup to turn source code into navigable Python object
from bs4 import BeautifulSoup
# Pandas to convert to DataFrame
import pandas as pd

# %%
# 1. Load page with list of events
# 2. Find individual events in source code
# 3. Loop through events and save details available
# 4. Turn to DataFrame
# 5. Loop through events and load detailed event page 
    # to save additional information

# %%
###############################################################################
####################### 1. LOAD PAGE WITH FUTURE EVENTS #######################
###############################################################################

# URL to BCCP events page
url = "http://www.bccp-berlin.de/events/all-events"
# Load URL
r = requests.get(url)

# %%
# Can check if successful (Code 200 means it worked without errors)
r
# Out:
# <Response [200]>

# %%
# Get source code
srccode = r.text
# This is now a string containing the entire source code:
srccode
# Out:
# '<!DOCTYPE html>\n<!--[if class="no-js">  <html class="ie ie6 lte9 lte8 lte7 no-js" lang="de"> <![endif]-->\n<!--[if IE 7]>     <html class="ie ie7 lte9 lte8 lte7 no-js" lang="de"> <![endif]-->\n<!--[if IE 8]>     <html class="ie ie8 lte9 lte8 no-js" lang="de"> <![endif]-->\n<!--[if IE 9]>     <html class="ie ie9 lte9 no-js" lang="de"> <![endif]-->\n<!--[if gt IE 9]>  <html class="no-js" lang="de"> <![endif]-->\n<!--[if !IE]><!--> <html class="no-js" lang="de"><!--<![endif]-->\n<head>\n\n<meta charset="utf-8" />\n<!-- \n\tCPS-IT GmbH http://www.cps-it.de/\n\n\tThis website is powered by TYPO3 - inspiring people to share!\n\tTYPO3 is a free open source Content Management Framework initially created by Kasper Skaarhoj and licensed under GNU/GPL.\n\tTYPO3 is copyright 1998-2016 of Kasper Skaarhoj. Extensions are copyright of their respective owners.\n\tInformation and contribution at http://typo3.org/\n-->\n\n<base href="http://www.bccp-berlin.de/" />\n<link rel="shortcut icon" href="/Templates/Master/Resources/Public/Images/favicon.ico" type="image/x-icon; charset=binary" />\n<link rel="icon" href="/Templates/Master/Resources/Public/Images/favicon.ico" type="image/x-icon; charset=binary" />\n\n<meta name="generator" content="TYPO3 CMS" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=0" />\n<meta name="revisit-after" content="5" />\n<meta name="google-site-verification" content="{$website.settings.meta.google_verify}" />\n<meta name="compatible" content="IE=edge,chrome=1" />\n<meta name="apple-mobile-web-app-capable" content="yes" />\n<meta name="apple-mobile-web-app-status-bar-style" content="{$website.settings.meta.apple-mobile-web-app-status-bar-style}" />\n<meta name="fullcss" content="Templates/Master/Resources/Public/Css/screen.min.css" />\n<meta name="fulljs" content="Templates/Master/Resources/Public/Javascript/javascript.min.js" />\n<meta name="fonts" content="http://fonts.googleapis.com/css?family=PT+Sans:400,700,400italic,700italic|PT+Serif:400,700,400italic,700italic" />\n<meta name="cache-control" content="no-cache" />\n<meta name="pragma" content="no-cache" />\n<meta name="language" content="en" />\n<meta name="content-language" content="en" />\n\n\n\n<style type="text/css">\n/*<![CDATA[*/\n<!-- \n/*TSFEinlineStyle*/\n/* default styles for extension "tx_cssstyledcontent" */\n\t/* Headers */\n\t.csc-header-alignment-center { text-align: center; }\n\t.csc-header-alignment-right { text-align: right; }\n\t.csc-header-alignment-left { text-align: left; }\n\n\tdiv.csc-textpic-responsive, div.csc-textpic-responsive * { -moz-box-sizing: border-box; -webkit-box-sizing: border-box; box-sizing: border-box;  }\n\n\t/* Clear floats after csc-textpic and after csc-textpic-imagerow */\n\tdiv.csc-textpic, div.csc-textpic div.csc-textpic-imagerow, ul.csc-uploads li { overflow: hidden; }\n\n\t/* Set padding for tables */\n\tdiv.csc-textpic .csc-textpic-imagewrap table { border-collapse: collapse; border-spacing: 0; }\n\tdiv.csc-textpic .csc-textpic-imagewrap table tr td { padding: 0; vertical-align: top; }\n\n\t/* Settings for figure and figcaption (HTML5) */\n\tdiv.csc-textpic .csc-textpic-imagewrap figure, div.csc-textpic figure.csc-textpic-imagewrap { margin: 0; display: table; }\n\n\t/* Captions */\n\tfigcaption.csc-textpic-caption { display: table-caption; }\n\t.csc-textpic-caption { text-align: left; caption-side: bottom; }\n\tdiv.csc-textpic-caption-c .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-c { text-align: center; }\n\tdiv.csc-textpic-caption-r .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-r { text-align: right; }\n\tdiv.csc-textpic-caption-l .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-l { text-align: left; }\n\n\t/* Float the columns */\n\tdiv.csc-textpic div.csc-textpic-imagecolumn { float: left; }\n\n\t/* Border just around the image */\n\tdiv.csc-textpic-border div.csc-textpic-imagewrap img {\n\t\tbo ...

# %%
# Use BeautifulSoup 4 to turn into soup object that allows navigation
soup = BeautifulSoup(srccode, "lxml")
# Look at the soup object:
soup
# Out:
# <!DOCTYPE html>
# <!--[if class="no-js">  <html class="ie ie6 lte9 lte8 lte7 no-js" lang="de"> <![endif]--><!--[if IE 7]>     <html class="ie ie7 lte9 lte8 lte7 no-js" lang="de"> <![endif]--><!--[if IE 8]>     <html class="ie ie8 lte9 lte8 no-js" lang="de"> <![endif]--><!--[if IE 9]>     <html class="ie ie9 lte9 no-js" lang="de"> <![endif]--><!--[if gt IE 9]>  <html class="no-js" lang="de"> <![endif]--><!--[if !IE]><!--><html class="no-js" lang="de"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!--
# 	CPS-IT GmbH http://www.cps-it.de/
#
# 	This website is powered by TYPO3 - inspiring people to share!
# 	TYPO3 is a free open source Content Management Framework initially created by Kasper Skaarhoj and licensed under GNU/GPL.
# 	TYPO3 is copyright 1998-2016 of Kasper Skaarhoj. Extensions are copyright of their respective owners.
# 	Information and contribution at http://typo3.org/
# -->
# <base href="http://www.bccp-berlin.de/"/>
# <link href="/Templates/Master/Resources/Public/Images/favicon.ico" rel="shortcut icon" type="image/x-icon; charset=binary"/>
# <link href="/Templates/Master/Resources/Public/Images/favicon.ico" rel="icon" type="image/x-icon; charset=binary"/>
# <meta content="TYPO3 CMS" name="generator"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=0" name="viewport"/>
# <meta content="5" name="revisit-after"/>
# <meta content="{$website.settings.meta.google_verify}" name="google-site-verification"/>
# <meta content="IE=edge,chrome=1" name="compatible"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="{$website.settings.meta.apple-mobile-web-app-status-bar-style}" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="Templates/Master/Resources/Public/Css/screen.min.css" name="fullcss"/>
# <meta content="Templates/Master/Resources/Public/Javascript/javascript.min.js" name="fulljs"/>
# <meta content="http://fonts.googleapis.com/css?family=PT+Sans:400,700,400italic,700italic|PT+Serif:400,700,400italic,700italic" name="fonts"/>
# <meta content="no-cache" name="cache-control"/>
# <meta content="no-cache" name="pragma"/>
# <meta content="en" name="language"/>
# <meta content="en" name="content-language"/>
# <style type="text/css">
# /*<![CDATA[*/
# <!--
# /*TSFEinlineStyle*/
# /* default styles for extension "tx_cssstyledcontent" */
# 	/* Headers */
# 	.csc-header-alignment-center { text-align: center; }
# 	.csc-header-alignment-right { text-align: right; }
# 	.csc-header-alignment-left { text-align: left; }
#
# 	div.csc-textpic-responsive, div.csc-textpic-responsive * { -moz-box-sizing: border-box; -webkit-box-sizing: border-box; box-sizing: border-box;  }
#
# 	/* Clear floats after csc-textpic and after csc-textpic-imagerow */
# 	div.csc-textpic, div.csc-textpic div.csc-textpic-imagerow, ul.csc-uploads li { overflow: hidden; }
#
# 	/* Set padding for tables */
# 	div.csc-textpic .csc-textpic-imagewrap table { border-collapse: collapse; border-spacing: 0; }
# 	div.csc-textpic .csc-textpic-imagewrap table tr td { padding: 0; vertical-align: top; }
#
# 	/* Settings for figure and figcaption (HTML5) */
# 	div.csc-textpic .csc-textpic-imagewrap figure, div.csc-textpic figure.csc-textpic-imagewrap { margin: 0; display: table; }
#
# 	/* Captions */
# 	figcaption.csc-textpic-caption { display: table-caption; }
# 	.csc-textpic-caption { text-align: left; caption-side: bottom; }
# 	div.csc-textpic-caption-c .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-c { text-align: center; }
# 	div.csc-textpic-caption-r .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-r { text-align: right; }
# 	div.csc-textpic-caption-l .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-l { text-align: left; }
#
# 	/* Float the columns */
# 	div.csc-textpic div.csc-textpic-imagecolumn { float: left; }
#
# 	/* Border just around the image */
# 	div.csc-textpic-border div.csc-textpic-imagewrap img {
# 		border: 1 # Image row separation: Whether images should be rendered/wrapped in separated rows, e.g. inside a div.csc-textpic-imagerow elementpx solid #000;
# 		padding: 0px 0px;
# 	}
#
# 	div.csc-textpic .csc-textpic-imagewrap img { border: none; display: block; }
#
# 	/* Space below each image (also in-between rows) */
# 	div.csc-textpic .csc-textpic-imagewrap .csc-textpic-image { margin-bottom: 20 # Margin to text: Horizontal distance between an imageblock and text in content elements of type "Text & Images".px; }
# 	div.csc-textpic .csc-textpic-imagewrap .csc-textpic-imagerow-last .csc-textpic-image { margin-bottom: 0; }
#
# 	/* colSpace around image columns, except for last column */
# 	div.csc-textpic-imagecolumn, td.csc-textpic-imagecolumn .csc-textpic-image { margin-right: 20 # Row space: Vertical distance after each image row in content elements of type "Images" or "Text & Images". If you change this manually in your CSS, you need to adjust this setting accordingly.px; }
# 	div.csc-textpic-imagecolumn.csc-textpic-lastcol, td.csc-textpic-imagecolumn.csc-textpic-lastcol .csc-textpic-image { margin-right: 0; }
#
# 	/* Add margin from image-block to text (in case of "Text & Images") */
# 	div.csc-textpic-intext-left .csc-textpic-imagewrap,
# 	div.csc-textpic-intext-left-nowrap .csc-textpic-imagewrap {
# 		margin-right: 20 # Image border, thickness: Thickness of border around images in content elements when "Border"-option for element is set.px;
# 	}
# 	div.csc-textpic-intext-right .csc-textpic-imagewrap,
# 	div.csc-textpic-intext-right-nowrap .csc-textpic-imagewrap {
# 		margin-left: 20 # Image border, thickness: Thickness of border around images in content elements when "Border"-option for element is set.px;
# 	}
#
# 	/* Positioning of images: */
#
# 	/* Center (above or below) */
# 	div.csc-textpic-center .csc-textpic-imagewrap, div.csc-textpic-center figure.csc-textpic-imagewrap { overflow: hidden; }
# 	div.csc-textpic-center .csc-textpic-center-outer { position: relative; float: right; right: 50%; }
# 	div.csc-textpic-center .csc-textpic-center-inner { position: relative; float: right; right: -50%; }
#
# 	/* Right (above or below) */
# 	div.csc-textpic-right .csc-textpic-imagewrap { float: right; }
# 	div.csc-textpic-right div.csc-textpic-text { clear: right; }
#
# 	/* Left (above or below) */
# 	div.csc-textpic-left .csc-textpic-imagewrap { float: left; }
# 	div.csc-textpic-left div.csc-textpic-text { clear: left; }
#
# 	/* Left (in text) */
# 	div.csc-textpic-intext-left .csc-textpic-imagewrap { float: left; }
#
# 	/* Right (in text) */
# 	div.csc-textpic-intext-right .csc-textpic-imagewrap { float: right; }
#
# 	/* Right (in text, no wrap around) */
# 	div.csc-textpic-intext-right-nowrap .csc-textpic-imagewrap { float: right; }
#
# 	/* Left (in text, no wrap around) */
# 	div.csc-textpic-intext-left-nowrap .csc-textpic-imagewrap { float: left; }
#
# 	div.csc-textpic div.csc-textpic-imagerow-last, div.csc-textpic div.csc-textpic-imagerow-none div.csc-textpic-last { margin-bottom: 0; }
#
# 	/* Browser fixes: */
#
# 	/* Fix for unordered and ordered list with image "In text, left" */
# 	.csc-textpic-intext-left ol, .csc-textpic-intext-left ul { padding-left: 40px; overflow: auto; }
#
# 	/* File Links */
# 	ul.csc-uploads { padding: 0; }
# 	ul.csc-uploads li { list-style: none outside none; margin: 1em 0; }
# 	ul.csc-uploads img { float: left; margin-right: 1em; vertical-align: top; }
# 	ul.csc-uploads span { display: block; }
# 	ul.csc-uploads span.csc-uploads-fileName { text-decoration: underline; }
#
# 	/* Table background colors: */
#
# 	table.contenttable-color-1 { background-color: #EDEBF1; }
# 	table.contenttable-color-2 { background-color: #F5FFAA; }
# 	table.contenttable-color-240 { background-color: black; }
# 	table.contenttable-color-241 { background-color: white; }
# 	table.contenttable-color-242 { background-color: #333333; }
# 	table.contenttable-color-243 { background-color: gray; }
# 	table.contenttable-color-244 { background-color: silver; }
# /*additionalTSFEInlineStyle*/
#
# .align-left {text-align: left;}
# .align-center {text-align: center;}
# .align-right {text-align: right;}
# .csc-frame-frame1 {background-color: #EDEBF1; border: 1px solid #333333;}
# .csc-frame-frame2 {background-color: #F5FFAA; border: 1px solid #333333;}
# .important {color: #8A0020;}
# .name-of-person {color: #10007B;}
# .detail {color: #186900;}
# .component-items {color: #186900;}
# .action-items {color: #8A0020;}
# .component-items-ordered {color: #186900;}
# .action-items-ordered {color: #8A0020;}
# .indent {margin-left:2em;}
# -->
# /*]]>*/
# </style>
# <script type="text/javascript">
# /*<![CDATA[*/
# /*TS_inlineJS*/
#
# window.Modernizr=function(e,t,n){function r(e){y.cssText=e}function o(e,t){return typeof e===t}function i(e,t){return!!~(""+e).indexOf(t)}function a(e,t){for(var r in e){var o=e[r];if(!i(o,"-")&&y[o]!==n)return"pfx"!=t||o}return!1}function c(e,t,r){for(var i in e){var a=t[e[i]];if(a!==n)return r===!1?e[i]:o(a,"function")?a.bind(r||t):a}return!1}function s(e,t,n){var r=e.charAt(0).toUpperCase()+e.slice(1),i=(e+" "+C.join(r+" ")+r).split(" ");return o(t,"string")||o(t,"undefined")?a(i,t):(i=(e+" "+S.join(r+" ")+r).split(" "),c(i,t,n))}var l,u,f,d="2.8.3",m={},p=!0,h=t.documentElement,v="modernizr",g=t.createElement(v),y=g.style,E={}.toString,b=" -webkit- -moz- -o- -ms- ".split(" "),w="Webkit Moz O ms",C=w.split(" "),S=w.toLowerCase().split(" "),N={svg:"http://www.w3.org/2000/svg"},x={},T=[],F=T.slice,j=function(e,n,r,o){var i,a,c,s,l=t.createElement("div"),u=t.body,f=u||t.createElement("body");if(parseInt(r,10))for(;r--;)c=t.createElement("div"),c.id=o?o[r]:v+(r+1),l.appendChild(c);return i=["&#173;",'<style id="s',v,'">',e,"</style>"].join(""),l.id=v,(u?l:f).innerHTML+=i,f.appendChild(l),u||(f.style.background="",f.style.overflow="hidden",s=h.style.overflow,h.style.overflow="hidden",h.appendChild(f)),a=n(l,e),u?l.parentNode.removeChild(l):(f.parentNode.removeChild(f),h.style.overflow=s),!!a},k={}.hasOwnProperty;f=o(k,"undefined")||o(k.call,"undefined")?function(e,t){return t in e&&o(e.constructor.prototype[t],"undefined")}:function(e,t){return k.call(e,t)},Function.prototype.bind||(Function.prototype.bind=function(e){var t=this;if("function"!=typeof t)throw new TypeError;var n=F.call(arguments,1),r=function(){if(this instanceof r){var o=function(){};o.prototype=t.prototype;var i=new o,a=t.apply(i,n.concat(F.call(arguments)));return Object(a)===a?a:i}return t.apply(e,n.concat(F.call(arguments)))};return r}),x.touch=function(){var n;return"ontouchstart"in e||e.DocumentTouch&&t instanceof DocumentTouch?n=!0:j(["@media (",b.join("touch-enabled),("),v,")","{#modernizr{top:9px;position:absolute}}"].join(""),function(e){n=9===e.offsetTop}),n},x.backgroundsize=function(){return s("backgroundSize")},x.cssanimations=function(){return s("animationName")},x.csstransforms=function(){return!!s("transform")},x.csstransforms3d=function(){var e=!!s("perspective");return e&&"webkitPerspective"in h.style&&j("@media (transform-3d),(-webkit-transform-3d){#modernizr{left:9px;position:absolute;height:3px;}}",function(t,n){e=9===t.offsetLeft&&3===t.offsetHeight}),e},x.csstransitions=function(){return s("transition")},x.fontface=function(){var e;return j('@font-face {font-family:"font";src:url("https://")}',function(n,r){var o=t.getElementById("smodernizr"),i=o.sheet||o.styleSheet,a=i?i.cssRules&&i.cssRules[0]?i.cssRules[0].cssText:i.cssText||"":"";e=/src/i.test(a)&&0===a.indexOf(r.split(" ")[0])}),e},x.svg=function(){return!!t.createElementNS&&!!t.createElementNS(N.svg,"svg").createSVGRect},x.inlinesvg=function(){var e=t.createElement("div");return e.innerHTML="<svg/>",(e.firstChild&&e.firstChild.namespaceURI)==N.svg},x.svgclippaths=function(){return!!t.createElementNS&&/SVGClipPath/.test(E.call(t.createElementNS(N.svg,"clipPath")))};for(var z in x)f(x,z)&&(u=z.toLowerCase(),m[u]=x[z](),T.push((m[u]?"":"no-")+u));return m.addTest=function(e,t){if("object"==typeof e)for(var r in e)f(e,r)&&m.addTest(r,e[r]);else{if(e=e.toLowerCase(),m[e]!==n)return m;t="function"==typeof t?t():t,"undefined"!=typeof p&&p&&(h.className+=" "+(t?"":"no-")+e),m[e]=t}return m},r(""),g=l=null,function(e,t){function n(e,t){var n=e.createElement("p"),r=e.getElementsByTagName("head")[0]||e.documentElement;return n.innerHTML="x<style>"+t+"</style>",r.insertBefore(n.lastChild,r.firstChild)}function r(){var e=y.elements;return"string"==typeof e?e.split(" "):e}function o(e){var t=g[e[h]];return t||(t={},v++,e[h]=v,g[v]=t),t}function i(e,n,r){if(n||(n=t),u)return n.createElement(e);r||(r=o(n));var i;return i=r.cache[e]?r.cache[e].cloneNode():p.test(e)?(r.cache[e]=r.createElem(e)).clon ...
#
#
# /*]]>*/
# </script>
# <title>All Events</title>
# <!--#if expr="$HTTP_COOKIE=/fullcss\=true/" -->
# <link href="Templates/Master/Resources/Public/Css/screen.min.css" rel="stylesheet"/>
# <!--#else -->
# <!--#if expr="$HTTP_COOKIE=/fonts\=true/" -->
# <link href="http://fonts.googleapis.com/css?family=PT+Sans:400,700,400italic,700italic|PT+Serif:400,700,400italic,700italic" rel="stylesheet"/>
# <!--#else -->
# <noscript>
# <link href="Templates/Master/Resources/Public/Css/screen.min.css" rel="stylesheet"/>
# </noscript>
# <!--#endif -->
# <!--#endif -->
# <link href="http://www.bccp-berlin.de/" hreflang="x-default" rel="alternate"/>
# <link href="http://www.bccp-berlin.de/en/" hreflang="en-GB" rel="alternate"/>
# <meta content="index,follow" name="robots"/>
# </head>
# <body class="layout_col2" id="skip-begin">
# <div class="l-page">
# <div class="l-pageWrapper">
# <header class="b-header" role="banner">
# <div class="g-container g-clearfix">
# <div class="b-logo">
# <div class="b-logo___left">
# <a href="/" title="Zur Startseite von GM3"><img alt="Logo GM3" height="90" src="/Templates/Master/Resources/Public/Images/bccp_logo_transparent.png" width="190"/></a>
# <div class="b-logoleibniz">
# <a href="http://www.leibniz-gemeinschaft.de/" target="_top" title="Zur Startseite von GM3"><img alt="Logo GM3" height="85" src="/Templates/Master/Resources/Public/Images/leibniz_logo_transparent.png" width="130"/></a>
# </div>
# </div>
# <div class="b-logo___right">
# <nav class="b-serviceMenu">
# <ul class="b-serviceMenu__list b-serviceMenu__list--level1"><li class="b-serviceMenu__list__item b-menuSub-list__item--first"><a href="/news/">News</a></li><li class="b-serviceMenu__list__item"><a href="/about/">About</a></li><li class="b-serviceMenu__list__item"><a href="/contact/">Contact</a></li><li class="b-serviceMenu__list__item b-menuSub-list__item--last"><a href="/imprint/">Imprint</a></li></ul>
# </nav>
# <div class="b-mMenu-trigger-mobile" id="js-mMenu-trigger-mobile">
# <span>Menu</span>
# </div>
# </div>
# <div class="g-clearfix"></div>
# </div>
# </div>
# <div class="b-mainMenuWrapper">
# <div class="b-mMenu-trigger-desktop" id="js-mMenu-trigger-desktop">
# <span>Menu</span>
# </div>
# <nav class="b-mMenu" id="js-mMenu">
# <div class="g-container">
# <ul class="b-mMenu__list b-mMenu__list--level1"><li class="b-mMenu__list__item--first b-mMenu__list__item--active"><a class="active" href="/events/all-events/?no_cache=1">Events</a><ul class="b-mMenu__list--lvl2"><li class="b-mMenu__list__item--first b-mMenu__list__item--current"><a class="current" href="/events/all-events/?no_cache=1">All Events</a></li><li><a href="/events/berlin-applied-micro-seminar/">Berlin Applied Micro Seminar</a></li><li><a href="/events/berlin-behavioral-economics-seminar/">Berlin Behavioral Economics Seminar</a></li><li><a href="/events/berlin-micro-theory-seminar/">Berlin Micro Theory Seminar</a></li><li><a href="/events/berlin-io-day/">Berlin IO Day</a></li><li><a href="/events/bccp-conference-and-policy-forum/">BCCP Conference and Policy Forum</a></li><li><a href="/events/behavioural-insights-series/">Behavioural Insights Series</a></li><li><a href="/events/lectures-in-consumer-and-competition-law/">Lectures in Consumer and Competition Law</a></li><li class="b-mMenu__list__item--last"><a href="/events/other-events/">Other events</a></li></ul></li><li><a href="/people/">People</a><ul class="b-mMenu__list--lvl2"><li class="b-mMenu__list__item--first"><a href="/people/bccp-fellows/">BCCP Fellows</a></li><li><a href="/people/board-of-directors/">Board of Directors</a></li><li><a href="/people/advisory-board/">Advisory Board</a></li><li class="b-mMenu__list__item--last"><a href="/people/guests/">Guests</a></li></ul></li><li class="b-mMenu__list__item--last"><a href="/research/">Research</a><ul class="b-mMenu__list--lvl2"><li class="b-mMenu__list__item--first"><a href="/research/consumer-and-market-behavior/">Consumer and Market Behavior</a></li><li><a href="/research/policy-design/">Policy Design</a></li><li><a href="/research/policy-evaluation/">Policy Evaluation</a></li><li class="b-mMenu__list__item--last"><a href="/research/publications/">Publications</a></li></ul></li></ul>
# <div class="g-clearfix"></div>
# </div>
# </nav><!--end .b-mMenu-->
# </div>
# </header>
# <div class="b-headerImg">
# <div class="headerBox__bg__mobile"></div>
# <div class="g-container">
# <div class="headerBox">
# <h1>All Events</h1>
# </div>
# </div>
# </div>
# <div class="b-breadcrumb">
# <div class="g-container g-clearfix">
# <div itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><ul class="b-breadcrumb__list"><li class="b-breadcrumb__list__item b-breadcrumb__list__item--first"><span itemprop="title"><a class="b-breadcrumb__list__item--link" href="/" itemprop="url" title="Home">Home</a></span> » </li><li class="b-breadcrumb__list__item"><span itemprop="title"><a class="b-breadcrumb__list__item--link" href="/events/all-events/?no_cache=1" itemprop="url" title="Events">Events</a></span> » </li><li class="b-breadcrumb__list__item--cur"><span itemprop="title">All Events</span></li></ul></div>
# </div>
# </div>
# <div class="l-main" role="main">
# <div class="b-content">
# <!--TYPO3SEARCH_begin-->
# <div class="g-container g-clearfix">
# <section class="b-main__sectionMain">
# <div class="b-contentMain" id="skip-inhalt">
# <div class="csc-default" id="c119"><div class="csc-header csc-header-n1"><h2 class="csc-firstHeader">Upcoming Events</h2></div>
# <div class="tx-t3events">
# <div class="eventList">
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						June 17, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Applied Micro Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/tba-27/">
# 					Sandra McNally (University of Surrey and LSE)
# 				</a>
# </h2>
# <div class="teaser">Closing the Gap Between Vocational and General Education? - Evidence from University Technical Colleges in England</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Humboldt-Universität zu Berlin</span>
# <span class="address">Spandauer Str. 1, Room 22</span>
# <span class="zip">10178</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:00–17:15</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/tba-27/" title="Sandra McNally (University of Surrey and LSE)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						June 17, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/ricardo-alonso-london-school-of-economics-1/">
# 					Ricardo Alonso (London School of Economics)
# 				</a>
# </h2>
# <div class="teaser">Tampering with Information</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/ricardo-alonso-london-school-of-economics-1/" title="Ricardo Alonso (London School of Economics)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						June 20, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Behavioral Economics Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/martin-sefton-university-of-nottingham/">
# 					Martin Sefton (University of Nottingham)
# 				</a>
# </h2>
# <div class="teaser">Communication with partially verifiable information: An experiment</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B 002/003</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/martin-sefton-university-of-nottingham/" title="Martin Sefton (University of Nottingham)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type2">
# <div class="top-bar">
# <span class="date single">
# 						June 21, 2019
# 					</span>
# <span class="b-events__item__type">Conference &amp; Events</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							BCCP Conference
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/bccp-conference-and-policy-forum-2019/">
# 					BCCP Conference and Policy Forum 2019
# 				</a>
# </h2>
# <div class="teaser">Regulatory Challenges in Digital Markets: the Rise of Corporate Power</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room A300</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>09:50–16:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/bccp-conference-and-policy-forum-2019/" title="BCCP Conference and Policy Forum 2019">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						June 24, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/matthias-lang-lmu-munich-1/">
# 					Matthias Lang (LMU Munich)
# 				</a>
# </h2>
# <div class="teaser">Bilateral Trade with Justification</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/matthias-lang-lmu-munich-1/" title="Matthias Lang (LMU Munich)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type2">
# <div class="top-bar">
# <span class="date range" title="">June 24, 2019 - June 26, 2019</span>
# <span class="b-events__item__type">Conference &amp; Events</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Other events
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/julian-harke-and-kevin-tran/">
# 					DIW Graduate Center/BCCP Short Course on Web Scraping
# 				</a>
# </h2>
# <div class="teaser"></div>
# <div class="date">
# <strong class="label">Date</strong>
# <span>June 25, 2019</span>
# </div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">DIW</span>
# <span class="address">Mohrenstr. 58, Room Anna J. Schwartz</span>
# <span class="zip">10117</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>09:30–12:30</span>
# </div>
# <div class="date">
# <strong class="label">Date</strong>
# <span>June 26, 2019</span>
# </div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">DIW</span>
# <span class="address">Mohrenstr. 58, Room Anna J. Schwartz</span>
# <span class="zip">10117</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>14:00–17:00</span>
# </div>
# <div class="date">
# <strong class="label">Date</strong>
# <span>June 24, 2019</span>
# </div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">DIW</span>
# <span class="address">Mohrenstr. 58, Room Anna J. Schwartz</span>
# <span class="zip">10117</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>09:30–12:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/julian-harke-and-kevin-tran/" title="DIW Graduate Center/BCCP Short Course on Web Scraping">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						June 27, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Behavioral Economics Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/felix-holzmeister-university-of-innsbruck/">
# 					Felix Holzmeister (University of Innsbruck)
# 				</a>
# </h2>
# <div class="teaser">Delegated decision making in finance</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/felix-holzmeister-university-of-innsbruck/" title="Felix Holzmeister (University of Innsbruck)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						July 01, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Applied Micro Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/bettina-siflinger-tilburg-university/">
# 					Bettina Siflinger (Tilburg University)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Humboldt-Universität zu Berlin</span>
# <span class="address">Spandauer Str. 1, Room 22</span>
# <span class="zip">10178</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:00–17:15</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/bettina-siflinger-tilburg-university/" title="Bettina Siflinger (Tilburg University)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						July 01, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/ariel-rubinstein-tel-aviv-university-2/">
# 					Ariel Rubinstein (Tel Aviv University)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/ariel-rubinstein-tel-aviv-university-2/" title="Ariel Rubinstein (Tel Aviv University)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						July 08, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/antonio-rosato-ut-sydney-1/">
# 					Antonio Rosato (UT Sydney)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/antonio-rosato-ut-sydney-1/" title="Antonio Rosato (UT Sydney)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type2">
# <div class="top-bar">
# <span class="date single">
# 						September 20, 2019
# 					</span>
# <span class="b-events__item__type">Conference &amp; Events</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin IO Day
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/12th-berlin-io-day/">
# 					12th Berlin IO Day
# 				</a>
# </h2>
# <div class="teaser"></div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Technische Universität Berlin</span>
# <span class="address">Straße des 17. Juni 135</span>
# <span class="zip"></span>
# <span class="place"></span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>09:00–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/12th-berlin-io-day/" title="12th Berlin IO Day">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						October 21, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/joergen-weibull-stockholm-school-of-economics-1/">
# 					Jörgen Weibull (Stockholm School of Economics)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/joergen-weibull-stockholm-school-of-economics-1/" title="Jörgen Weibull (Stockholm School of Economics)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						October 24, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Behavioral Economics Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/tom-chang-university-of-southern-california/">
# 					Tom Chang (University of Southern California)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/tom-chang-university-of-southern-california/" title="Tom Chang (University of Southern California)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						October 28, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/jidong-zhou-yale-som-1/">
# 					Jidong Zhou (Yale)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B 002/003</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/jidong-zhou-yale-som-1/" title="Jidong Zhou (Yale)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						October 31, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Behavioral Economics Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/tim-cason-purdue-university/">
# 					Tim Cason (Purdue University)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Technische Universität Berlin</span>
# <span class="address">Ernst-Reuter-Platz 1, Room BH-N 243</span>
# <span class="zip">10587</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/tim-cason-purdue-university/" title="Tim Cason (Purdue University)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						November 07, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/paul-heidhues-dice/">
# 					Paul Heidhues (DICE)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/paul-heidhues-dice/" title="Paul Heidhues (DICE)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						November 07, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Behavioral Economics Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/paul-heidhues-duesseldorf-institute-for-competition-economics-dice/">
# 					Paul Heidhues (Düsseldorf Institute for Competition Economics (DICE))
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/paul-heidhues-duesseldorf-institute-for-competition-economics-dice/" title="Paul Heidhues (Düsseldorf Institute for Competition Economics (DICE))">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						November 11, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/andrew-rhodes-tse-1/">
# 					Andrew Rhodes (TSE)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room D118/119</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/andrew-rhodes-tse-1/" title="Andrew Rhodes (TSE)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						November 14, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Behavioral Economics Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/ala-avoyan-indiana-university/">
# 					Ala Avoyan (Indiana University)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Technische Universität Berlin</span>
# <span class="address">Ernst-Reuter-Platz 1, Room BH-N 243</span>
# <span class="zip">10587</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/ala-avoyan-indiana-university/" title="Ala Avoyan (Indiana University)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						November 25, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/florian-scheuer-university-of-zurich-1/">
# 					Florian Scheuer (University of Zurich)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/florian-scheuer-university-of-zurich-1/" title="Florian Scheuer (University of Zurich)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						December 02, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/yair-antlertel-aviv-university-1/">
# 					Yair Antler (Tel Aviv University)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/yair-antlertel-aviv-university-1/" title="Yair Antler (Tel Aviv University)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						December 05, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Behavioral Economics Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/andreas-lange-university-of-hamburg/">
# 					Andreas Lange (University of Hamburg)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Technische Universität Berlin</span>
# <span class="address">Ernst-Reuter-Platz 1, Room BH-N 243</span>
# <span class="zip">10587</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/andreas-lange-university-of-hamburg/" title="Andreas Lange (University of Hamburg)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						December 12, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Behavioral Economics Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/marco-faravelli-university-of-queensland/">
# 					Marco Faravelli (University of Queensland)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Technische Universität Berlin</span>
# <span class="address">Ernst-Reuter-Platz 1, Room BH-N 243</span>
# <span class="zip">10587</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:45–18:00</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/marco-faravelli-university-of-queensland/" title="Marco Faravelli (University of Queensland)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						December 16, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/alexandre-de-cornieretse-1/">
# 					Alexandre de Cornière (TSE)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/alexandre-de-cornieretse-1/" title="Alexandre de Cornière (TSE)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						February 03, 2020
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Micro Theory Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/christian-hofmann-lmu/">
# 					Christian Hofmann (LMU)
# 				</a>
# </h2>
# <div class="teaser">TBA</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">WZB</span>
# <span class="address">Reichpietschufer 50, Room B001</span>
# <span class="zip">10785</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>17:15–18:30</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/christian-hofmann-lmu/" title="Christian Hofmann (LMU)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <aside class="b-main__sectionRight">
# <div class="b-contentRight">
# <div class="csc-frame frame_grey" id="c455"><div class="csc-header csc-header-n1"><h6 class="h6_small_underline">Calendar</h6></div>
# <div class="tx-t3events">
# <a name="calendar" style="position:relative; top:-110px;display: block;visibility: hidden;"></a>
# <div class="c-cal-sheet__nav">
# <a class="c-cal-sheet__nav-item c-cal-sheet__nav-item--prev" href="/events/all-events/?no_cache=1&amp;tx_t3events_events%5Bmonth%5D=5&amp;tx_t3events_events%5Byear%5D=2019&amp;cHash=488cb7c46d8f1f2c116c07d28881ae88#calendar">
# 					&lt;
# 				</a>
# <span class="c-cal-sheet__date">June 2019</span>
# <a class="c-cal-sheet__nav-item c-cal-sheet__nav-item--next" href="/events/all-events/?no_cache=1&amp;tx_t3events_events%5Bmonth%5D=7&amp;tx_t3events_events%5Byear%5D=2019&amp;cHash=3b795476b918a292a489e87dd8b5b97c#calendar">
# 					&gt;
# 				</a>
# </div>
# <table class="c-cal-sheet">
# <thead class="c-cal-sheet__header">
# <tr>
# <th class="c-cal-sheet__cell c-cal-sheet__cell--header">M</th>
# <th class="c-cal-sheet__cell c-cal-sheet__cell--header">T</th>
# <th class="c-cal-sheet__cell c-cal-sheet__cell--header">W</th>
# <th class="c-cal-sheet__cell c-cal-sheet__cell--header">T</th>
# <th class="c-cal-sheet__cell c-cal-sheet__cell--header">F</th>
# <th class="c-cal-sheet__cell c-cal-sheet__cell--header">S</th>
# <th class="c-cal-sheet__cell c-cal-sheet__cell--header">S</th>
# </tr>
# </thead>
# <tbody class="c-cal-sheet__body">
# <tr>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day is-empty"></td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day is-empty"></td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day is-empty"></td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day is-empty"></td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day is-empty"></td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											01
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											02
# 										</td>
# </tr><tr>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											03
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/tba-26/">
# 																Eve Caroli (Université Paris Dauphine and Paris School of Economics)
# 															</a>
# </li>
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/peter-norman-soerensen-university-of-copenhagen-1/">
# 																Peter Norman Sørensen (University of Copenhagen)
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											04
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											05
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											06
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/barton-lipman-boston-university/">
# 																Barton Lipman (Boston University)
# 															</a>
# </li>
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/tobias-gesche-eth-zurich/">
# 																Tobias Gesche (ETH Zurich)
# 															</a>
# </li>
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/hsog-applied-micro-workshop/">
# 																HSoG Applied Micro Workshop
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											07
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											08
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											09
# 										</td>
# </tr><tr>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											10
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											11
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/andreas-steinmayr-lmu/">
# 																Andreas Steinmayr (LMU)
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											12
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											13
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											14
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											15
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											16
# 										</td>
# </tr><tr>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											17
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/tba-27/">
# 																Sandra McNally (University of Surrey and LSE)
# 															</a>
# </li>
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/ricardo-alonso-london-school-of-economics-1/">
# 																Ricardo Alonso (London School of Economics)
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											18
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											19
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											20
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/martin-sefton-university-of-nottingham/">
# 																Martin Sefton (University of Nottingham)
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											21
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/bccp-conference-and-policy-forum-2019/">
# 																BCCP Conference and Policy Forum 2019
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											22
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											23
# 										</td>
# </tr><tr>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											24
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/matthias-lang-lmu-munich-1/">
# 																Matthias Lang (LMU Munich)
# 															</a>
# </li>
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/julian-harke-and-kevin-tran/">
# 																DIW Graduate Center/BCCP Short Course on Web Scraping
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											25
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/julian-harke-and-kevin-tran/">
# 																DIW Graduate Center/BCCP Short Course on Web Scraping
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											26
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/julian-harke-and-kevin-tran/">
# 																DIW Graduate Center/BCCP Short Course on Web Scraping
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day has-events">
# 											27
# 											<div class="c-cal-sheet__tooltip">
# <ul class="c-cal-sheet__events">
# <li class="c-cal-sheet__event">
# <a class="c-cal-sheet__event-link" href="/events/all-events/events-detail/felix-holzmeister-university-of-innsbruck/">
# 																Felix Holzmeister (University of Innsbruck)
# 															</a>
# </li>
# </ul>
# </div>
# </td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											28
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											29
# 										</td>
# <td class="c-cal-sheet__cell c-cal-sheet__cell--day">
# 											30
# 										</td>
# </tr><tr>
# </tr>
# </tbody>
# </table>
# </div>
# </div><div class="csc-frame frame_grey" id="c476"><div class="csc-header csc-header-n2"><h6 class="h6_small_underline">Subscribe to Calendar</h6></div><table cellpadding="2" cellspacing="2" class="contenttable" summary=""><tbody><tr style="background:#e9eff4"><td><a class="rte_btn_red" href="http://bccp-berlin.de/events/all-events/?no_cache=1&amp;type=120" target="_blank" title="Opens external link in new window">ics-file</a></td><td class="align-right"><a class="rte_btn_red" href="http://www.google.com/calendar/render?cid=http://bccp-berlin.de/events/all-events/?type=120&amp;no_cache=1" target="_blank" title="Opens external link in new window">Google Cal</a></td></tr></tbody></table></div><div class="csc-frame frame_grey" id="c153"><div class="csc-header csc-header-n3"><h6 class="h6_small_underline">Show Events by Event Category</h6></div><p class="bodytext"><a class="internal-link" href="/events/berlin-applied-micro-seminar/" title="Opens internal link in current window">Berlin Applied Micro Seminar</a><br/><a class="internal-link" href="/events/berlin-behavioral-economics-seminar/" title="Opens internal link in current window">Berlin Behavioral Economics Seminar</a><br/><a class="internal-link" href="/events/berlin-micro-theory-seminar/" title="Opens internal link in current window">Berlin Micro Theory Seminar</a><br/><a class="internal-link" href="/events/bccp-conference-and-policy-forum/" title="Opens internal link in current window">BCCP Conference and Policy Forum</a><br/><a class="internal-link" href="/events/berlin-io-day/" title="Opens internal link in current window">Berlin IO Day</a><br/><a class="internal-link" href="/events/behavioural-insights-series/" title="Opens internal link in current window">Behavioural Insights Series</a><a class="internal-link" href="/events/lectures-in-consumer-and-competition-law/" title="Opens internal link in current window"><br/>Lectures in Consumer and Competition Law</a><br/><a class="internal-link" href="/events/other-events/" title="Opens internal link in current window">Other events</a></p></div>
# </div>
# </aside>
# </div>
# <!--TYPO3SEARCH_end-->
# </div>
# </div>
# <footer class="footer" role="contentinfo">
# <div class="g-container">
# <div class="b-footerCopyright">
# <p class="copyright">© Copyright 2018 - BCCP</p>
# </div>
# <div class="b-footerToTop">
# <a class="toTopLink btnLink" href="/events/all-events/?no_cache=1#skip-begin" id="toTop" title="Back to top">Back to top</a>
# </div>
# <div class="b-footerNavigation">
# <ul class="nav-footer"><li class="b-menuFooter-list__item--first"><a href="/contact/" title="Contact">Contact</a></li><li class="b-menuFooter-list__item--last"><a href="/imprint/" title="Imprint">Imprint</a></li></ul>
# </div>
# </div>
# </footer>
# </div>
# <div class="l-menuMobileWrapper">
# <nav class="b-mainMenuMobile" id="mobileMenu">
# <ul class="b-mobileMenu__list">
# <li class="b-mobileMenu__list__item b-mobileMenu__list__item--closer">
# <a href="/events/all-events/?no_cache=1#">Menü</a>
# </li>
# <li class="b-mobileMenu__list__item b-mobileMenu__list__item--events"><a class="active" href="/events/all-events/?no_cache=1">Events</a><ul class="b-mobileMenu__list--lvl2"><li class="b-mobileMenu__list__item b-mobileMenu__list__item--events"><a class="current" href="/events/all-events/?no_cache=1">All Events</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--people"><a href="/events/berlin-applied-micro-seminar/">Berlin Applied Micro Seminar</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/berlin-behavioral-economics-seminar/">Berlin Behavioral Economics Seminar</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/berlin-micro-theory-seminar/">Berlin Micro Theory Seminar</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/berlin-io-day/">Berlin IO Day</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/bccp-conference-and-policy-forum/">BCCP Conference and Policy Forum</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/behavioural-insights-series/">Behavioural Insights Series</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/lectures-in-consumer-and-competition-law/">Lectures in Consumer and Competition Law</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/other-events/">Other events</a></li></ul></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--people"><a href="/people/">People</a><ul class="b-mobileMenu__list--lvl2"><li class="b-mobileMenu__list__item b-mobileMenu__list__item--events"><a href="/people/bccp-fellows/">BCCP Fellows</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--people"><a href="/people/board-of-directors/">Board of Directors</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/people/advisory-board/">Advisory Board</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/people/guests/">Guests</a></li></ul></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/research/">Research</a><ul class="b-mobileMenu__list--lvl2"><li class="b-mobileMenu__list__item b-mobileMenu__list__item--events"><a href="/research/consumer-and-market-behavior/">Consumer and Market Behavior</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--people"><a href="/research/policy-design/">Policy Design</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/research/policy-evaluation/">Policy Evaluation</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/research/publications/">Publications</a></li></ul></li>
# <li class="b-mobileMenu__list__item b-mobileMenu__list__item--service"><a href="/news/">News</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--service"><a href="/about/">About</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--service"><a href="/contact/">Contact</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--service"><a href="/imprint/">Imprint</a></li>
# </ul>
# </nav>
# </div>
# </div>
# <!-- Piwik DIW anonymisiert bccp -->
# <script type="text/javascript">
# 	var _paq = _paq || [];
# 	_paq.push(['trackPageView']);
# 	_paq.push(['enableLinkTracking']);
# 	(function() {
# 		var u="//piwik.diw.de/piwik/";
# 		_paq.push(['setTrackerUrl', u+'piwik.php']);
# 		_paq.push(['setSiteId', 23]);
# 		var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
# 		g.type='text/javascript'; g.async=true; g.defer=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
# 	})();
# </script>
# <noscript><p><img alt="" src="//piwik.diw.de/piwik/piwik.php?idsite=23" style="border:0;"/></p></noscript>
# <!-- End Piwik Code -->
# </body>
# </html>

# %%
# This object now has several useful properties and functions that we can use.
# The documentation is also very good: 
print("https://www.crummy.com/software/BeautifulSoup/bs4/doc/")
# Out:
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
###############################################################################
######################### 2. FIND INDIVIDUAL LISTINGS #########################
###############################################################################

# Search soup for all "div" tags whose "class" attribute 
# contains "event-list-item"
divs = soup.find_all("div", class_ = "event-list-item")
# Note normally, the attribute can just be used as an option
# e.g. if it where "id": soup.find_all("div", id = "event-list-item")
# but because "class" coindides with the Python class object, for class
# attributes, you have to use "class_"
# Alternatively: 
# divs = soup.find_all("div", attrs = {"class": "event-list-item"})

# This returns a list containing all div elements that match this structure
# Check the number of events:
len(divs)
# Out:
# 25

# %%
# Take a look at the first element in the list
div = divs[0]
div
# Out:
# <div class="event-list-item event-type1">
# <div class="top-bar">
# <span class="date single">
# 						June 17, 2019
# 					</span>
# <span class="b-events__item__type">Seminar</span>
# </div>
# <div class="b-events__item__inner">
# <div class="content">
# <div class="genres">
#
# 							Berlin Applied Micro Seminar
#
# 					</div>
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/tba-27/">
# 					Sandra McNally (University of Surrey and LSE)
# 				</a>
# </h2>
# <div class="teaser">Closing the Gap Between Vocational and General Education? - Evidence from University Technical Colleges in England</div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Humboldt-Universität zu Berlin</span>
# <span class="address">Spandauer Str. 1, Room 22</span>
# <span class="zip">10178</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>16:00–17:15</span>
# </div>
# </div>
# <div class="button detail">
# <a href="/events/all-events/events-detail/tba-27/" title="Sandra McNally (University of Surrey and LSE)">
# 				Event Details
# 			</a>
# </div>
# </div>
# </div>

# %%
# Get details and save in dict
divdict = {}
# Date:
date = div.find("span", class_ = "date")
# Note: .find() only takes the first element that matches the structure
# If you are not sure that there is always a unique element that matches,
# a more conservative approach could be:
# Find all elements that fit the search
date = div.find_all("span", class_ = "date")
# Make sure the result is unique
assert len(date) == 1, "%d results for //span[@class='date']" \
    % len(date)
# If there is not exactly one result, this will raise an Exception.
# If it is a unique result, the code continues:
# Take the result (remember the .find_all() yields a list of result)
date = date[0].text.strip()

# Save in dict
divdict["date"] = date

# Look at the date element:
date
# Out:
# 'June 17, 2019'

# %%
# Save event type
evtype = div.find("span", class_ = "b-events__item__type").text.strip()
divdict["event_type"] = evtype
evtype
# Out:
# 'Seminar'

# %%
# Save seminar series
series = div.find("div", class_ = "genres").text.strip()
divdict["event_series"] = series
series
# Out:
# 'Berlin Applied Micro Seminar'

# %%
# Save URL and title
header = div.find("h2", class_ = "eventHeader")
header
# Out:
# <h2 class="eventHeader">
# <a href="/events/all-events/events-detail/tba-27/">
# 					Sandra McNally (University of Surrey and LSE)
# 				</a>
# </h2>

# %%
# Get URL
# Note that the URL is not saved as content but as the value of the "href" attribute
url = header.find("a")["href"]
url 
# Add base URL
url = "http://www.bccp-berlin.de" + url
url
# Out:
# '/events/all-events/events-detail/tba-27/'
# 'http://www.bccp-berlin.de/events/all-events/events-detail/tba-27/'

# %%
# Get title
title = header.text.strip()
title
# Save both
divdict["url"] = url
divdict["title"] = title
# Out:
# 'Sandra McNally (University of Surrey and LSE)'

# %%
# Save topic
topic = div.find("div", class_ = "teaser").text.strip()
topic
divdict["topic"] = topic
# Out:
# 'Closing the Gap Between Vocational and General Education? - Evidence from University Technical Colleges in England'

# %%
# Get address
addtag = div.find("div", class_ = "address")
addtag
# Out:
# <div class="address">
# <span class="name">Humboldt-Universität zu Berlin</span>
# <span class="address">Spandauer Str. 1, Room 22</span>
# <span class="zip">10178</span>
# <span class="place">Berlin</span>
# </div>

# %%
# Loop through sub "span" elements and save
for span in addtag.find_all("span"):
    # Take content
    val = span.text
    # Use class as variable name (add prefix)
    varname = "loc_" + span["class"][0]
    divdict[varname] = val
divdict
# Note: Approaching it like this automates the creation of the variable
# and makes the code more flexible (e.g. if there are different address
# elements in different events)
# On the other hand, this flexibility increases the probability that
# errors are missed (e.g. if a listing was not correctly loaded,
# this might just create no variable and go on)
# Out:
# {'date': 'June 17, 2019',
#  'event_type': 'Seminar',
#  'event_series': 'Berlin Applied Micro Seminar',
#  'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/tba-27/',
#  'title': 'Sandra McNally (University of Surrey and LSE)',
#  'topic': 'Closing the Gap Between Vocational and General Education? - Evidence from University Technical Colleges in England',
#  'loc_name': 'Humboldt-Universität zu Berlin',
#  'loc_address': 'Spandauer Str. 1, Room 22',
#  'loc_zip': '10178',
#  'loc_place': 'Berlin'}

# %%
# Get time
time = div.find("div", class_ = "time").find("span").text.strip()
time
divdict["time"] = time
# Out:
# '16:00–17:15'

# %%
# Look at divdict
divdict
# Out:
# {'date': 'June 17, 2019',
#  'event_type': 'Seminar',
#  'event_series': 'Berlin Applied Micro Seminar',
#  'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/tba-27/',
#  'title': 'Sandra McNally (University of Surrey and LSE)',
#  'topic': 'Closing the Gap Between Vocational and General Education? - Evidence from University Technical Colleges in England',
#  'loc_name': 'Humboldt-Universität zu Berlin',
#  'loc_address': 'Spandauer Str. 1, Room 22',
#  'loc_zip': '10178',
#  'loc_place': 'Berlin',
#  'time': '16:00–17:15'}

# %%
###############################################################################
########################### 3. LOOP THROUGH LISTINGS ##########################
###############################################################################

# Now put this inside a loop to loop through all events
# Loop through events and save details in dictionary
resdict = {}
for div in divs:
    
    # Get details and save in dict
    divdict = {}
    
    # Date:
    date = div.find_all("span", class_ = "date")
    # Make sure the result is unique
    assert len(date) == 1, "%d results for //span[@class='date single']" \
        % len(date)
    # If there is not exactly one result, this will raise an Exception.
    # If it is a unique result, the code continues:
    # Take the result (remember the .find_all() yields a list of result)
    date = date[0].text.strip()
    # Save in dict
    divdict["date"] = date

    # Save event type
    evtype = div.find("span", class_ = "b-events__item__type").text.strip()
    divdict["event_type"] = evtype

    # Save seminar series
    series = div.find("div", class_ = "genres").text.strip()
    divdict["event_series"] = series

    # Save URL and title
    header = div.find("h2", class_ = "eventHeader")
    # Get URL
    # Note that the URL is not saved as content but as the value of the "href" attribute
    url = header.find("a")["href"] 
    # Add base URL
    url = "http://www.bccp-berlin.de" + url

    # Get title
    title = header.text.strip()

    # Save both
    divdict["url"] = url
    divdict["title"] = title

    # Save topic
    topic = div.find("div", class_ = "teaser").text.strip()
    divdict["topic"] = topic

    # Get address
    addtag = div.find("div", class_ = "address")

    # Loop through sub "span" elements and save
    for span in addtag.find_all("span"):
        # Take content
        val = span.text
        # Use class as variable name (add prefix)
        varname = "loc_" + span["class"][0]
        divdict[varname] = val

    # Get time
    time = div.find("div", class_ = "time").find("span").text.strip()
    divdict["time"] = time
    
    # Save as new entry in resdict
    resdict[len(resdict)] = divdict

# Look at resdict
resdict
# Out:
# {0: {'date': 'June 17, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Applied Micro Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/tba-27/',
#   'title': 'Sandra McNally (University of Surrey and LSE)',
#   'topic': 'Closing the Gap Between Vocational and General Education? - Evidence from University Technical Colleges in England',
#   'loc_name': 'Humboldt-Universität zu Berlin',
#   'loc_address': 'Spandauer Str. 1, Room 22',
#   'loc_zip': '10178',
#   'loc_place': 'Berlin',
#   'time': '16:00–17:15'},
#  1: {'date': 'June 17, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/ricardo-alonso-london-school-of-economics-1/',
#   'title': 'Ricardo Alonso (London School of Economics)',
#   'topic': 'Tampering with Information',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  2: {'date': 'June 20, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Behavioral Economics Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/martin-sefton-university-of-nottingham/',
#   'title': 'Martin Sefton (University of Nottingham)',
#   'topic': 'Communication with partially verifiable information: An experiment',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B 002/003',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  3: {'date': 'June 21, 2019',
#   'event_type': 'Conference & Events',
#   'event_series': 'BCCP Conference',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/bccp-conference-and-policy-forum-2019/',
#   'title': 'BCCP Conference and Policy Forum 2019',
#   'topic': 'Regulatory Challenges in Digital Markets: the Rise of Corporate Power',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room A300',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '09:50–16:30'},
#  4: {'date': 'June 24, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/matthias-lang-lmu-munich-1/',
#   'title': 'Matthias Lang (LMU Munich)',
#   'topic': 'Bilateral Trade with Justification',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  5: {'date': 'June 24, 2019 - June 26, 2019',
#   'event_type': 'Conference & Events',
#   'event_series': 'Other events',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/julian-harke-and-kevin-tran/',
#   'title': 'DIW Graduate Center/BCCP Short Course on Web Scraping',
#   'topic': '',
#   'loc_name': 'DIW',
#   'loc_address': 'Mohrenstr. 58, Room Anna J. Schwartz',
#   'loc_zip': '10117',
#   'loc_place': 'Berlin',
#   'time': '09:30–12:30'},
#  6: {'date': 'June 27, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Behavioral Economics Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/felix-holzmeister-university-of-innsbruck/',
#   'title': 'Felix Holzmeister (University of Innsbruck)',
#   'topic': 'Delegated decision making in finance',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  7: {'date': 'July 01, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Applied Micro Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/bettina-siflinger-tilburg-university/',
#   'title': 'Bettina Siflinger (Tilburg University)',
#   'topic': 'TBA',
#   'loc_name': 'Humboldt-Universität zu Berlin',
#   'loc_address': 'Spandauer Str. 1, Room 22',
#   'loc_zip': '10178',
#   'loc_place': 'Berlin',
#   'time': '16:00–17:15'},
#  8: {'date': 'July 01, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/ariel-rubinstein-tel-aviv-university-2/',
#   'title': 'Ariel Rubinstein (Tel Aviv University)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  9: {'date': 'July 08, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/antonio-rosato-ut-sydney-1/',
#   'title': 'Antonio Rosato (UT Sydney)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  10: {'date': 'September 20, 2019',
#   'event_type': 'Conference & Events',
#   'event_series': 'Berlin IO Day',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/12th-berlin-io-day/',
#   'title': '12th Berlin IO Day',
#   'topic': '',
#   'loc_name': 'Technische Universität Berlin',
#   'loc_address': 'Straße des 17. Juni 135',
#   'loc_zip': '',
#   'loc_place': '',
#   'time': '09:00–18:00'},
#  11: {'date': 'October 21, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/joergen-weibull-stockholm-school-of-economics-1/',
#   'title': 'Jörgen Weibull (Stockholm School of Economics)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  12: {'date': 'October 24, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Behavioral Economics Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/tom-chang-university-of-southern-california/',
#   'title': 'Tom Chang (University of Southern California)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  13: {'date': 'October 28, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/jidong-zhou-yale-som-1/',
#   'title': 'Jidong Zhou (Yale)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B 002/003',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  14: {'date': 'October 31, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Behavioral Economics Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/tim-cason-purdue-university/',
#   'title': 'Tim Cason (Purdue University)',
#   'topic': 'TBA',
#   'loc_name': 'Technische Universität Berlin',
#   'loc_address': 'Ernst-Reuter-Platz 1, Room BH-N 243',
#   'loc_zip': '10587',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  15: {'date': 'November 07, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/paul-heidhues-dice/',
#   'title': 'Paul Heidhues (DICE)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  16: {'date': 'November 07, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Behavioral Economics Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/paul-heidhues-duesseldorf-institute-for-competition-economics-dice/',
#   'title': 'Paul Heidhues (Düsseldorf Institute for Competition Economics (DICE))',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  17: {'date': 'November 11, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/andrew-rhodes-tse-1/',
#   'title': 'Andrew Rhodes (TSE)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room D118/119',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  18: {'date': 'November 14, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Behavioral Economics Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/ala-avoyan-indiana-university/',
#   'title': 'Ala Avoyan (Indiana University)',
#   'topic': 'TBA',
#   'loc_name': 'Technische Universität Berlin',
#   'loc_address': 'Ernst-Reuter-Platz 1, Room BH-N 243',
#   'loc_zip': '10587',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  19: {'date': 'November 25, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/florian-scheuer-university-of-zurich-1/',
#   'title': 'Florian Scheuer (University of Zurich)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  20: {'date': 'December 02, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/yair-antlertel-aviv-university-1/',
#   'title': 'Yair Antler\xa0(Tel Aviv University)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  21: {'date': 'December 05, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Behavioral Economics Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/andreas-lange-university-of-hamburg/',
#   'title': 'Andreas Lange (University of Hamburg)',
#   'topic': 'TBA',
#   'loc_name': 'Technische Universität Berlin',
#   'loc_address': 'Ernst-Reuter-Platz 1, Room BH-N 243',
#   'loc_zip': '10587',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  22: {'date': 'December 12, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Behavioral Economics Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/marco-faravelli-university-of-queensland/',
#   'title': 'Marco Faravelli (University of Queensland)',
#   'topic': 'TBA',
#   'loc_name': 'Technische Universität Berlin',
#   'loc_address': 'Ernst-Reuter-Platz 1, Room BH-N 243',
#   'loc_zip': '10587',
#   'loc_place': 'Berlin',
#   'time': '16:45–18:00'},
#  23: {'date': 'December 16, 2019',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/alexandre-de-cornieretse-1/',
#   'title': 'Alexandre de Cornière\xa0(TSE)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'},
#  24: {'date': 'February 03, 2020',
#   'event_type': 'Seminar',
#   'event_series': 'Berlin Micro Theory Seminar',
#   'url': 'http://www.bccp-berlin.de/events/all-events/events-detail/christian-hofmann-lmu/',
#   'title': 'Christian Hofmann (LMU)',
#   'topic': 'TBA',
#   'loc_name': 'WZB',
#   'loc_address': 'Reichpietschufer 50, Room B001',
#   'loc_zip': '10785',
#   'loc_place': 'Berlin',
#   'time': '17:15–18:30'}}

# %%
###############################################################################
############################# 4. TURN TO DATAFRAME ############################
###############################################################################

# Turn to dataframe and transpose
df = pd.DataFrame(resdict).T
# Look at df
df
# Out:
#                              date                         event_series  \
# 0                   June 17, 2019         Berlin Applied Micro Seminar
# 1                   June 17, 2019          Berlin Micro Theory Seminar
# 2                   June 20, 2019  Berlin Behavioral Economics Seminar
# 3                   June 21, 2019                      BCCP Conference
# 4                   June 24, 2019          Berlin Micro Theory Seminar
# 5   June 24, 2019 - June 26, 2019                         Other events
# 6                   June 27, 2019  Berlin Behavioral Economics Seminar
# 7                   July 01, 2019         Berlin Applied Micro Seminar
# 8                   July 01, 2019          Berlin Micro Theory Seminar
# 9                   July 08, 2019          Berlin Micro Theory Seminar
# 10             September 20, 2019                        Berlin IO Day
# 11               October 21, 2019          Berlin Micro Theory Seminar
# 12               October 24, 2019  Berlin Behavioral Economics Seminar
# 13               October 28, 2019          Berlin Micro Theory Seminar
# 14               October 31, 2019  Berlin Behavioral Economics Seminar
# 15              November 07, 2019          Berlin Micro Theory Seminar
# 16              November 07, 2019  Berlin Behavioral Economics Seminar
# 17              November 11, 2019          Berlin Micro Theory Seminar
# 18              November 14, 2019  Berlin Behavioral Economics Seminar
# 19              November 25, 2019          Berlin Micro Theory Seminar
# 20              December 02, 2019          Berlin Micro Theory Seminar
# 21              December 05, 2019  Berlin Behavioral Economics Seminar
# 22              December 12, 2019  Berlin Behavioral Economics Seminar
# 23              December 16, 2019          Berlin Micro Theory Seminar
# 24              February 03, 2020          Berlin Micro Theory Seminar
#
#              event_type                           loc_address  \
# 0               Seminar             Spandauer Str. 1, Room 22
# 1               Seminar        Reichpietschufer 50, Room B001
# 2               Seminar   Reichpietschufer 50, Room B 002/003
# 3   Conference & Events        Reichpietschufer 50, Room A300
# 4               Seminar        Reichpietschufer 50, Room B001
# 5   Conference & Events  Mohrenstr. 58, Room Anna J. Schwartz
# 6               Seminar        Reichpietschufer 50, Room B001
# 7               Seminar             Spandauer Str. 1, Room 22
# 8               Seminar        Reichpietschufer 50, Room B001
# 9               Seminar        Reichpietschufer 50, Room B001
# 10  Conference & Events               Straße des 17. Juni 135
# 11              Seminar        Reichpietschufer 50, Room B001
# 12              Seminar        Reichpietschufer 50, Room B001
# 13              Seminar   Reichpietschufer 50, Room B 002/003
# 14              Seminar   Ernst-Reuter-Platz 1, Room BH-N 243
# 15              Seminar        Reichpietschufer 50, Room B001
# 16              Seminar        Reichpietschufer 50, Room B001
# 17              Seminar    Reichpietschufer 50, Room D118/119
# 18              Seminar   Ernst-Reuter-Platz 1, Room BH-N 243
# 19              Seminar        Reichpietschufer 50, Room B001
# 20              Seminar        Reichpietschufer 50, Room B001
# 21              Seminar   Ernst-Reuter-Platz 1, Room BH-N 243
# 22              Seminar   Ernst-Reuter-Platz 1, Room BH-N 243
# 23              Seminar        Reichpietschufer 50, Room B001
# 24              Seminar        Reichpietschufer 50, Room B001
#
#                           loc_name loc_place loc_zip         time  \
# 0   Humboldt-Universität zu Berlin    Berlin   10178  16:00–17:15
# 1                              WZB    Berlin   10785  17:15–18:30
# 2                              WZB    Berlin   10785  16:45–18:00
# 3                              WZB    Berlin   10785  09:50–16:30
# 4                              WZB    Berlin   10785  17:15–18:30
# 5                              DIW    Berlin   10117  09:30–12:30
# 6                              WZB    Berlin   10785  16:45–18:00
# 7   Humboldt-Universität zu Berlin    Berlin   10178  16:00–17:15
# 8                              WZB    Berlin   10785  17:15–18:30
# 9                              WZB    Berlin   10785  17:15–18:30
# 10   Technische Universität Berlin                    09:00–18:00
# 11                             WZB    Berlin   10785  17:15–18:30
# 12                             WZB    Berlin   10785  16:45–18:00
# 13                             WZB    Berlin   10785  17:15–18:30
# 14   Technische Universität Berlin    Berlin   10587  16:45–18:00
# 15                             WZB    Berlin   10785  16:45–18:00
# 16                             WZB    Berlin   10785  16:45–18:00
# 17                             WZB    Berlin   10785  17:15–18:30
# 18   Technische Universität Berlin    Berlin   10587  16:45–18:00
# 19                             WZB    Berlin   10785  17:15–18:30
# 20                             WZB    Berlin   10785  17:15–18:30
# 21   Technische Universität Berlin    Berlin   10587  16:45–18:00
# 22   Technische Universität Berlin    Berlin   10587  16:45–18:00
# 23                             WZB    Berlin   10785  17:15–18:30
# 24                             WZB    Berlin   10785  17:15–18:30
#
#                                                 title  \
# 0       Sandra McNally (University of Surrey and LSE)
# 1         Ricardo Alonso (London School of Economics)
# 2            Martin Sefton (University of Nottingham)
# 3               BCCP Conference and Policy Forum 2019
# 4                          Matthias Lang (LMU Munich)
# 5   DIW Graduate Center/BCCP Short Course on Web S...
# 6         Felix Holzmeister (University of Innsbruck)
# 7              Bettina Siflinger (Tilburg University)
# 8              Ariel Rubinstein (Tel Aviv University)
# 9                          Antonio Rosato (UT Sydney)
# 10                                 12th Berlin IO Day
# 11     Jörgen Weibull (Stockholm School of Economics)
# 12      Tom Chang (University of Southern California)
# 13                                 Jidong Zhou (Yale)
# 14                      Tim Cason (Purdue University)
# 15                               Paul Heidhues (DICE)
# 16  Paul Heidhues (Düsseldorf Institute for Compet...
# 17                                Andrew Rhodes (TSE)
# 18                    Ala Avoyan (Indiana University)
# 19             Florian Scheuer (University of Zurich)
# 20                  Yair Antler (Tel Aviv University)
# 21              Andreas Lange (University of Hamburg)
# 22         Marco Faravelli (University of Queensland)
# 23                        Alexandre de Cornière (TSE)
# 24                            Christian Hofmann (LMU)
#
#                                                 topic  \
# 0   Closing the Gap Between Vocational and General...
# 1                          Tampering with Information
# 2   Communication with partially verifiable inform...
# 3   Regulatory Challenges in Digital Markets: the ...
# 4                  Bilateral Trade with Justification
# 5
# 6                Delegated decision making in finance
# 7                                                 TBA
# 8                                                 TBA
# 9                                                 TBA
# 10
# 11                                                TBA
# 12                                                TBA
# 13                                                TBA
# 14                                                TBA
# 15                                                TBA
# 16                                                TBA
# 17                                                TBA
# 18                                                TBA
# 19                                                TBA
# 20                                                TBA
# 21                                                TBA
# 22                                                TBA
# 23                                                TBA
# 24                                                TBA
#
#                                                   url
# 0   http://www.bccp-berlin.de/events/all-events/ev...
# 1   http://www.bccp-berlin.de/events/all-events/ev...
# 2   http://www.bccp-berlin.de/events/all-events/ev...
# 3   http://www.bccp-berlin.de/events/all-events/ev...
# 4   http://www.bccp-berlin.de/events/all-events/ev...
# 5   http://www.bccp-berlin.de/events/all-events/ev...
# 6   http://www.bccp-berlin.de/events/all-events/ev...
# 7   http://www.bccp-berlin.de/events/all-events/ev...
# 8   http://www.bccp-berlin.de/events/all-events/ev...
# 9   http://www.bccp-berlin.de/events/all-events/ev...
# 10  http://www.bccp-berlin.de/events/all-events/ev...
# 11  http://www.bccp-berlin.de/events/all-events/ev...
# 12  http://www.bccp-berlin.de/events/all-events/ev...
# 13  http://www.bccp-berlin.de/events/all-events/ev...
# 14  http://www.bccp-berlin.de/events/all-events/ev...
# 15  http://www.bccp-berlin.de/events/all-events/ev...
# 16  http://www.bccp-berlin.de/events/all-events/ev...
# 17  http://www.bccp-berlin.de/events/all-events/ev...
# 18  http://www.bccp-berlin.de/events/all-events/ev...
# 19  http://www.bccp-berlin.de/events/all-events/ev...
# 20  http://www.bccp-berlin.de/events/all-events/ev...
# 21  http://www.bccp-berlin.de/events/all-events/ev...
# 22  http://www.bccp-berlin.de/events/all-events/ev...
# 23  http://www.bccp-berlin.de/events/all-events/ev...
# 24  http://www.bccp-berlin.de/events/all-events/ev...

# %%
###############################################################################
######################### 5. LOAD EVENT DETAIL PAGES ##########################
###############################################################################

# Load url and turn to soup
url = df["url"].values[0]

r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if class="no-js">  <html class="ie ie6 lte9 lte8 lte7 no-js" lang="de"> <![endif]--><!--[if IE 7]>     <html class="ie ie7 lte9 lte8 lte7 no-js" lang="de"> <![endif]--><!--[if IE 8]>     <html class="ie ie8 lte9 lte8 no-js" lang="de"> <![endif]--><!--[if IE 9]>     <html class="ie ie9 lte9 no-js" lang="de"> <![endif]--><!--[if gt IE 9]>  <html class="no-js" lang="de"> <![endif]--><!--[if !IE]><!--><html class="no-js" lang="de"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!--
# 	CPS-IT GmbH http://www.cps-it.de/
#
# 	This website is powered by TYPO3 - inspiring people to share!
# 	TYPO3 is a free open source Content Management Framework initially created by Kasper Skaarhoj and licensed under GNU/GPL.
# 	TYPO3 is copyright 1998-2016 of Kasper Skaarhoj. Extensions are copyright of their respective owners.
# 	Information and contribution at http://typo3.org/
# -->
# <base href="http://www.bccp-berlin.de/"/>
# <link href="/Templates/Master/Resources/Public/Images/favicon.ico" rel="shortcut icon" type="image/x-icon; charset=binary"/>
# <link href="/Templates/Master/Resources/Public/Images/favicon.ico" rel="icon" type="image/x-icon; charset=binary"/>
# <title>Sandra McNally (University of Surrey and LSE)</title>
# <meta content="TYPO3 CMS" name="generator"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=0" name="viewport"/>
# <meta content="5" name="revisit-after"/>
# <meta content="{$website.settings.meta.google_verify}" name="google-site-verification"/>
# <meta content="IE=edge,chrome=1" name="compatible"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="{$website.settings.meta.apple-mobile-web-app-status-bar-style}" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="Templates/Master/Resources/Public/Css/screen.min.css" name="fullcss"/>
# <meta content="Templates/Master/Resources/Public/Javascript/javascript.min.js" name="fulljs"/>
# <meta content="http://fonts.googleapis.com/css?family=PT+Sans:400,700,400italic,700italic|PT+Serif:400,700,400italic,700italic" name="fonts"/>
# <meta content="en" name="language"/>
# <meta content="en" name="content-language"/>
# <style type="text/css">
# /*<![CDATA[*/
# <!--
# /*TSFEinlineStyle*/
# /* default styles for extension "tx_cssstyledcontent" */
# 	/* Headers */
# 	.csc-header-alignment-center { text-align: center; }
# 	.csc-header-alignment-right { text-align: right; }
# 	.csc-header-alignment-left { text-align: left; }
#
# 	div.csc-textpic-responsive, div.csc-textpic-responsive * { -moz-box-sizing: border-box; -webkit-box-sizing: border-box; box-sizing: border-box;  }
#
# 	/* Clear floats after csc-textpic and after csc-textpic-imagerow */
# 	div.csc-textpic, div.csc-textpic div.csc-textpic-imagerow, ul.csc-uploads li { overflow: hidden; }
#
# 	/* Set padding for tables */
# 	div.csc-textpic .csc-textpic-imagewrap table { border-collapse: collapse; border-spacing: 0; }
# 	div.csc-textpic .csc-textpic-imagewrap table tr td { padding: 0; vertical-align: top; }
#
# 	/* Settings for figure and figcaption (HTML5) */
# 	div.csc-textpic .csc-textpic-imagewrap figure, div.csc-textpic figure.csc-textpic-imagewrap { margin: 0; display: table; }
#
# 	/* Captions */
# 	figcaption.csc-textpic-caption { display: table-caption; }
# 	.csc-textpic-caption { text-align: left; caption-side: bottom; }
# 	div.csc-textpic-caption-c .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-c { text-align: center; }
# 	div.csc-textpic-caption-r .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-r { text-align: right; }
# 	div.csc-textpic-caption-l .csc-textpic-caption, .csc-textpic-imagewrap .csc-textpic-caption-l { text-align: left; }
#
# 	/* Float the columns */
# 	div.csc-textpic div.csc-textpic-imagecolumn { float: left; }
#
# 	/* Border just around the image */
# 	div.csc-textpic-border div.csc-textpic-imagewrap img {
# 		border: 1 # Image row separation: Whether images should be rendered/wrapped in separated rows, e.g. inside a div.csc-textpic-imagerow elementpx solid #000;
# 		padding: 0px 0px;
# 	}
#
# 	div.csc-textpic .csc-textpic-imagewrap img { border: none; display: block; }
#
# 	/* Space below each image (also in-between rows) */
# 	div.csc-textpic .csc-textpic-imagewrap .csc-textpic-image { margin-bottom: 20 # Margin to text: Horizontal distance between an imageblock and text in content elements of type "Text & Images".px; }
# 	div.csc-textpic .csc-textpic-imagewrap .csc-textpic-imagerow-last .csc-textpic-image { margin-bottom: 0; }
#
# 	/* colSpace around image columns, except for last column */
# 	div.csc-textpic-imagecolumn, td.csc-textpic-imagecolumn .csc-textpic-image { margin-right: 20 # Row space: Vertical distance after each image row in content elements of type "Images" or "Text & Images". If you change this manually in your CSS, you need to adjust this setting accordingly.px; }
# 	div.csc-textpic-imagecolumn.csc-textpic-lastcol, td.csc-textpic-imagecolumn.csc-textpic-lastcol .csc-textpic-image { margin-right: 0; }
#
# 	/* Add margin from image-block to text (in case of "Text & Images") */
# 	div.csc-textpic-intext-left .csc-textpic-imagewrap,
# 	div.csc-textpic-intext-left-nowrap .csc-textpic-imagewrap {
# 		margin-right: 20 # Image border, thickness: Thickness of border around images in content elements when "Border"-option for element is set.px;
# 	}
# 	div.csc-textpic-intext-right .csc-textpic-imagewrap,
# 	div.csc-textpic-intext-right-nowrap .csc-textpic-imagewrap {
# 		margin-left: 20 # Image border, thickness: Thickness of border around images in content elements when "Border"-option for element is set.px;
# 	}
#
# 	/* Positioning of images: */
#
# 	/* Center (above or below) */
# 	div.csc-textpic-center .csc-textpic-imagewrap, div.csc-textpic-center figure.csc-textpic-imagewrap { overflow: hidden; }
# 	div.csc-textpic-center .csc-textpic-center-outer { position: relative; float: right; right: 50%; }
# 	div.csc-textpic-center .csc-textpic-center-inner { position: relative; float: right; right: -50%; }
#
# 	/* Right (above or below) */
# 	div.csc-textpic-right .csc-textpic-imagewrap { float: right; }
# 	div.csc-textpic-right div.csc-textpic-text { clear: right; }
#
# 	/* Left (above or below) */
# 	div.csc-textpic-left .csc-textpic-imagewrap { float: left; }
# 	div.csc-textpic-left div.csc-textpic-text { clear: left; }
#
# 	/* Left (in text) */
# 	div.csc-textpic-intext-left .csc-textpic-imagewrap { float: left; }
#
# 	/* Right (in text) */
# 	div.csc-textpic-intext-right .csc-textpic-imagewrap { float: right; }
#
# 	/* Right (in text, no wrap around) */
# 	div.csc-textpic-intext-right-nowrap .csc-textpic-imagewrap { float: right; }
#
# 	/* Left (in text, no wrap around) */
# 	div.csc-textpic-intext-left-nowrap .csc-textpic-imagewrap { float: left; }
#
# 	div.csc-textpic div.csc-textpic-imagerow-last, div.csc-textpic div.csc-textpic-imagerow-none div.csc-textpic-last { margin-bottom: 0; }
#
# 	/* Browser fixes: */
#
# 	/* Fix for unordered and ordered list with image "In text, left" */
# 	.csc-textpic-intext-left ol, .csc-textpic-intext-left ul { padding-left: 40px; overflow: auto; }
#
# 	/* File Links */
# 	ul.csc-uploads { padding: 0; }
# 	ul.csc-uploads li { list-style: none outside none; margin: 1em 0; }
# 	ul.csc-uploads img { float: left; margin-right: 1em; vertical-align: top; }
# 	ul.csc-uploads span { display: block; }
# 	ul.csc-uploads span.csc-uploads-fileName { text-decoration: underline; }
#
# 	/* Table background colors: */
#
# 	table.contenttable-color-1 { background-color: #EDEBF1; }
# 	table.contenttable-color-2 { background-color: #F5FFAA; }
# 	table.contenttable-color-240 { background-color: black; }
# 	table.contenttable-color-241 { background-color: white; }
# 	table.contenttable-color-242 { background-color: #333333; }
# 	table.contenttable-color-243 { background-color: gray; }
# 	table.contenttable-color-244 { background-color: silver; }
# /*additionalTSFEInlineStyle*/
#
# .align-left {text-align: left;}
# .align-center {text-align: center;}
# .align-right {text-align: right;}
# .csc-frame-frame1 {background-color: #EDEBF1; border: 1px solid #333333;}
# .csc-frame-frame2 {background-color: #F5FFAA; border: 1px solid #333333;}
# .important {color: #8A0020;}
# .name-of-person {color: #10007B;}
# .detail {color: #186900;}
# .component-items {color: #186900;}
# .action-items {color: #8A0020;}
# .component-items-ordered {color: #186900;}
# .action-items-ordered {color: #8A0020;}
# .indent {margin-left:2em;}
# -->
# /*]]>*/
# </style>
# <script type="text/javascript">
# /*<![CDATA[*/
# /*TS_inlineJS*/
#
# window.Modernizr=function(e,t,n){function r(e){y.cssText=e}function o(e,t){return typeof e===t}function i(e,t){return!!~(""+e).indexOf(t)}function a(e,t){for(var r in e){var o=e[r];if(!i(o,"-")&&y[o]!==n)return"pfx"!=t||o}return!1}function c(e,t,r){for(var i in e){var a=t[e[i]];if(a!==n)return r===!1?e[i]:o(a,"function")?a.bind(r||t):a}return!1}function s(e,t,n){var r=e.charAt(0).toUpperCase()+e.slice(1),i=(e+" "+C.join(r+" ")+r).split(" ");return o(t,"string")||o(t,"undefined")?a(i,t):(i=(e+" "+S.join(r+" ")+r).split(" "),c(i,t,n))}var l,u,f,d="2.8.3",m={},p=!0,h=t.documentElement,v="modernizr",g=t.createElement(v),y=g.style,E={}.toString,b=" -webkit- -moz- -o- -ms- ".split(" "),w="Webkit Moz O ms",C=w.split(" "),S=w.toLowerCase().split(" "),N={svg:"http://www.w3.org/2000/svg"},x={},T=[],F=T.slice,j=function(e,n,r,o){var i,a,c,s,l=t.createElement("div"),u=t.body,f=u||t.createElement("body");if(parseInt(r,10))for(;r--;)c=t.createElement("div"),c.id=o?o[r]:v+(r+1),l.appendChild(c);return i=["&#173;",'<style id="s',v,'">',e,"</style>"].join(""),l.id=v,(u?l:f).innerHTML+=i,f.appendChild(l),u||(f.style.background="",f.style.overflow="hidden",s=h.style.overflow,h.style.overflow="hidden",h.appendChild(f)),a=n(l,e),u?l.parentNode.removeChild(l):(f.parentNode.removeChild(f),h.style.overflow=s),!!a},k={}.hasOwnProperty;f=o(k,"undefined")||o(k.call,"undefined")?function(e,t){return t in e&&o(e.constructor.prototype[t],"undefined")}:function(e,t){return k.call(e,t)},Function.prototype.bind||(Function.prototype.bind=function(e){var t=this;if("function"!=typeof t)throw new TypeError;var n=F.call(arguments,1),r=function(){if(this instanceof r){var o=function(){};o.prototype=t.prototype;var i=new o,a=t.apply(i,n.concat(F.call(arguments)));return Object(a)===a?a:i}return t.apply(e,n.concat(F.call(arguments)))};return r}),x.touch=function(){var n;return"ontouchstart"in e||e.DocumentTouch&&t instanceof DocumentTouch?n=!0:j(["@media (",b.join("touch-enabled),("),v,")","{#modernizr{top:9px;position:absolute}}"].join(""),function(e){n=9===e.offsetTop}),n},x.backgroundsize=function(){return s("backgroundSize")},x.cssanimations=function(){return s("animationName")},x.csstransforms=function(){return!!s("transform")},x.csstransforms3d=function(){var e=!!s("perspective");return e&&"webkitPerspective"in h.style&&j("@media (transform-3d),(-webkit-transform-3d){#modernizr{left:9px;position:absolute;height:3px;}}",function(t,n){e=9===t.offsetLeft&&3===t.offsetHeight}),e},x.csstransitions=function(){return s("transition")},x.fontface=function(){var e;return j('@font-face {font-family:"font";src:url("https://")}',function(n,r){var o=t.getElementById("smodernizr"),i=o.sheet||o.styleSheet,a=i?i.cssRules&&i.cssRules[0]?i.cssRules[0].cssText:i.cssText||"":"";e=/src/i.test(a)&&0===a.indexOf(r.split(" ")[0])}),e},x.svg=function(){return!!t.createElementNS&&!!t.createElementNS(N.svg,"svg").createSVGRect},x.inlinesvg=function(){var e=t.createElement("div");return e.innerHTML="<svg/>",(e.firstChild&&e.firstChild.namespaceURI)==N.svg},x.svgclippaths=function(){return!!t.createElementNS&&/SVGClipPath/.test(E.call(t.createElementNS(N.svg,"clipPath")))};for(var z in x)f(x,z)&&(u=z.toLowerCase(),m[u]=x[z](),T.push((m[u]?"":"no-")+u));return m.addTest=function(e,t){if("object"==typeof e)for(var r in e)f(e,r)&&m.addTest(r,e[r]);else{if(e=e.toLowerCase(),m[e]!==n)return m;t="function"==typeof t?t():t,"undefined"!=typeof p&&p&&(h.className+=" "+(t?"":"no-")+e),m[e]=t}return m},r(""),g=l=null,function(e,t){function n(e,t){var n=e.createElement("p"),r=e.getElementsByTagName("head")[0]||e.documentElement;return n.innerHTML="x<style>"+t+"</style>",r.insertBefore(n.lastChild,r.firstChild)}function r(){var e=y.elements;return"string"==typeof e?e.split(" "):e}function o(e){var t=g[e[h]];return t||(t={},v++,e[h]=v,g[v]=t),t}function i(e,n,r){if(n||(n=t),u)return n.createElement(e);r||(r=o(n));var i;return i=r.cache[e]?r.cache[e].cloneNode():p.test(e)?(r.cache[e]=r.createElem(e)).clon ...
#
#
# /*]]>*/
# </script>
# <title>Events Detail</title>
# <!--#if expr="$HTTP_COOKIE=/fullcss\=true/" -->
# <link href="Templates/Master/Resources/Public/Css/screen.min.css" rel="stylesheet"/>
# <!--#else -->
# <!--#if expr="$HTTP_COOKIE=/fonts\=true/" -->
# <link href="http://fonts.googleapis.com/css?family=PT+Sans:400,700,400italic,700italic|PT+Serif:400,700,400italic,700italic" rel="stylesheet"/>
# <!--#else -->
# <noscript>
# <link href="Templates/Master/Resources/Public/Css/screen.min.css" rel="stylesheet"/>
# </noscript>
# <!--#endif -->
# <!--#endif -->
# <link href="http://www.bccp-berlin.de/" hreflang="x-default" rel="alternate"/>
# <link href="http://www.bccp-berlin.de/en/" hreflang="en-GB" rel="alternate"/>
# <meta content="index,follow" name="robots"/>
# </head>
# <body class="layout_col1" id="skip-begin">
# <div class="l-page">
# <div class="l-pageWrapper">
# <header class="b-header" role="banner">
# <div class="g-container g-clearfix">
# <div class="b-logo">
# <div class="b-logo___left">
# <a href="/" title="Zur Startseite von GM3"><img alt="Logo GM3" height="90" src="/Templates/Master/Resources/Public/Images/bccp_logo_transparent.png" width="190"/></a>
# <div class="b-logoleibniz">
# <a href="http://www.leibniz-gemeinschaft.de/" target="_top" title="Zur Startseite von GM3"><img alt="Logo GM3" height="85" src="/Templates/Master/Resources/Public/Images/leibniz_logo_transparent.png" width="130"/></a>
# </div>
# </div>
# <div class="b-logo___right">
# <nav class="b-serviceMenu">
# <ul class="b-serviceMenu__list b-serviceMenu__list--level1"><li class="b-serviceMenu__list__item b-menuSub-list__item--first"><a href="/news/">News</a></li><li class="b-serviceMenu__list__item"><a href="/about/">About</a></li><li class="b-serviceMenu__list__item"><a href="/contact/">Contact</a></li><li class="b-serviceMenu__list__item b-menuSub-list__item--last"><a href="/imprint/">Imprint</a></li></ul>
# </nav>
# <div class="b-mMenu-trigger-mobile" id="js-mMenu-trigger-mobile">
# <span>Menu</span>
# </div>
# </div>
# <div class="g-clearfix"></div>
# </div>
# </div>
# <div class="b-mainMenuWrapper">
# <div class="b-mMenu-trigger-desktop" id="js-mMenu-trigger-desktop">
# <span>Menu</span>
# </div>
# <nav class="b-mMenu" id="js-mMenu">
# <div class="g-container">
# <ul class="b-mMenu__list b-mMenu__list--level1"><li class="b-mMenu__list__item--first b-mMenu__list__item--active"><a class="active" href="/events/all-events/?no_cache=1">Events</a><ul class="b-mMenu__list--lvl2"><li class="b-mMenu__list__item--first b-mMenu__list__item--active"><a class="active" href="/events/all-events/?no_cache=1">All Events</a></li><li><a href="/events/berlin-applied-micro-seminar/">Berlin Applied Micro Seminar</a></li><li><a href="/events/berlin-behavioral-economics-seminar/">Berlin Behavioral Economics Seminar</a></li><li><a href="/events/berlin-micro-theory-seminar/">Berlin Micro Theory Seminar</a></li><li><a href="/events/berlin-io-day/">Berlin IO Day</a></li><li><a href="/events/bccp-conference-and-policy-forum/">BCCP Conference and Policy Forum</a></li><li><a href="/events/behavioural-insights-series/">Behavioural Insights Series</a></li><li><a href="/events/lectures-in-consumer-and-competition-law/">Lectures in Consumer and Competition Law</a></li><li class="b-mMenu__list__item--last"><a href="/events/other-events/">Other events</a></li></ul></li><li><a href="/people/">People</a><ul class="b-mMenu__list--lvl2"><li class="b-mMenu__list__item--first"><a href="/people/bccp-fellows/">BCCP Fellows</a></li><li><a href="/people/board-of-directors/">Board of Directors</a></li><li><a href="/people/advisory-board/">Advisory Board</a></li><li class="b-mMenu__list__item--last"><a href="/people/guests/">Guests</a></li></ul></li><li class="b-mMenu__list__item--last"><a href="/research/">Research</a><ul class="b-mMenu__list--lvl2"><li class="b-mMenu__list__item--first"><a href="/research/consumer-and-market-behavior/">Consumer and Market Behavior</a></li><li><a href="/research/policy-design/">Policy Design</a></li><li><a href="/research/policy-evaluation/">Policy Evaluation</a></li><li class="b-mMenu__list__item--last"><a href="/research/publications/">Publications</a></li></ul></li></ul>
# <div class="g-clearfix"></div>
# </div>
# </nav><!--end .b-mMenu-->
# </div>
# </header>
# <div class="b-headerImg">
# <div class="headerBox__bg__mobile"></div>
# <div class="g-container">
# <div class="headerBox">
# <h1>Berlin Applied Micro Seminar</h1>
# </div>
# </div>
# </div>
# <div class="b-breadcrumb">
# <div class="g-container g-clearfix">
# <div itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><ul class="b-breadcrumb__list"><li class="b-breadcrumb__list__item b-breadcrumb__list__item--first"><span itemprop="title"><a class="b-breadcrumb__list__item--link" href="/" itemprop="url" title="Home">Home</a></span> » </li><li class="b-breadcrumb__list__item"><span itemprop="title"><a class="b-breadcrumb__list__item--link" href="/events/all-events/?no_cache=1" itemprop="url" title="Events">Events</a></span> » </li><li class="b-breadcrumb__list__item b-breadcrumb__list__item--last"><span itemprop="title"><a class="b-breadcrumb__list__item--link" href="/events/all-events/?no_cache=1" itemprop="url" title="All Events">All Events</a></span></li><li><span> › </span>Sandra McNally (University of Surrey and LSE)</li></ul></div>
# </div>
# </div>
# <div class="l-main" role="main">
# <div class="b-content">
# <!--TYPO3SEARCH_begin-->
# <div class="g-container g-clearfix">
# <section class="b-main__sectionMain">
# <div class="b-contentMain" id="skip-inhalt">
# <div class="csc-default" id="c120">
# <div class="tx-t3events">
# <a class="button back" href="/events/all-events/?no_cache=1&amp;cHash=9232b4ecf4af76e58332586a8e48b654">back to list</a>
# <div class="event-single">
# <h2 class="headline--mobile">
# 		Sandra McNally (University of Surrey and LSE)
# 	</h2>
# <div class="info-box">
# <strong class="label">Date</strong>
# <div class="date">
# <span class="date">
# 				June 17, 2019
# 			</span>
# </div>
# <div class="time">
# <strong class="label">Time</strong>
# <span>
# 				16:00–17:15
# 			</span>
# </div>
# <div class="location">
# <strong class="label">Location</strong>
# <div class="address">
# <span class="name">Humboldt-Universität zu Berlin</span>
# <span class="address">Spandauer Str. 1, Room 22</span>
# <span class="zip">10178</span>
# <span class="place">Berlin</span>
# </div>
# </div>
# </div>
# <div class="content">
# <div class="description">
# <h2 class="headline--desktop">
# 				Sandra McNally (University of Surrey and LSE)
# 			</h2>
# <h3 class="teaser">
# <strong class="label">Topic:</strong>Closing the Gap Between Vocational and General Education? - Evidence from University Technical Colleges in England
# 				</h3>
# <div class="description__bodytext">
# <p class="bodytext">
#
# 							Go to
# 							<a href="https://www.surrey.ac.uk/people/sandra-mcnally" target="_blank">speaker website</a>.<br/>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# <!--TYPO3SEARCH_end-->
# </div>
# </div>
# <footer class="footer" role="contentinfo">
# <div class="g-container">
# <div class="b-footerCopyright">
# <p class="copyright">© Copyright 2018 - BCCP</p>
# </div>
# <div class="b-footerToTop">
# <a class="toTopLink btnLink" href="/events/all-events/events-detail/tba-27/#skip-begin" id="toTop" title="Back to top">Back to top</a>
# </div>
# <div class="b-footerNavigation">
# <ul class="nav-footer"><li class="b-menuFooter-list__item--first"><a href="/contact/" title="Contact">Contact</a></li><li class="b-menuFooter-list__item--last"><a href="/imprint/" title="Imprint">Imprint</a></li></ul>
# </div>
# </div>
# </footer>
# </div>
# <div class="l-menuMobileWrapper">
# <nav class="b-mainMenuMobile" id="mobileMenu">
# <ul class="b-mobileMenu__list">
# <li class="b-mobileMenu__list__item b-mobileMenu__list__item--closer">
# <a href="/events/all-events/events-detail/tba-27/#">Menü</a>
# </li>
# <li class="b-mobileMenu__list__item b-mobileMenu__list__item--events"><a class="active" href="/events/all-events/?no_cache=1">Events</a><ul class="b-mobileMenu__list--lvl2"><li class="b-mobileMenu__list__item b-mobileMenu__list__item--events"><a class="active" href="/events/all-events/?no_cache=1">All Events</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--people"><a href="/events/berlin-applied-micro-seminar/">Berlin Applied Micro Seminar</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/berlin-behavioral-economics-seminar/">Berlin Behavioral Economics Seminar</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/berlin-micro-theory-seminar/">Berlin Micro Theory Seminar</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/berlin-io-day/">Berlin IO Day</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/bccp-conference-and-policy-forum/">BCCP Conference and Policy Forum</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/behavioural-insights-series/">Behavioural Insights Series</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/lectures-in-consumer-and-competition-law/">Lectures in Consumer and Competition Law</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/events/other-events/">Other events</a></li></ul></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--people"><a href="/people/">People</a><ul class="b-mobileMenu__list--lvl2"><li class="b-mobileMenu__list__item b-mobileMenu__list__item--events"><a href="/people/bccp-fellows/">BCCP Fellows</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--people"><a href="/people/board-of-directors/">Board of Directors</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/people/advisory-board/">Advisory Board</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/people/guests/">Guests</a></li></ul></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/research/">Research</a><ul class="b-mobileMenu__list--lvl2"><li class="b-mobileMenu__list__item b-mobileMenu__list__item--events"><a href="/research/consumer-and-market-behavior/">Consumer and Market Behavior</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--people"><a href="/research/policy-design/">Policy Design</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/research/policy-evaluation/">Policy Evaluation</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--research"><a href="/research/publications/">Publications</a></li></ul></li>
# <li class="b-mobileMenu__list__item b-mobileMenu__list__item--service"><a href="/news/">News</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--service"><a href="/about/">About</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--service"><a href="/contact/">Contact</a></li><li class="b-mobileMenu__list__item b-mobileMenu__list__item--service"><a href="/imprint/">Imprint</a></li>
# </ul>
# </nav>
# </div>
# </div>
# <!-- Piwik DIW anonymisiert bccp -->
# <script type="text/javascript">
# 	var _paq = _paq || [];
# 	_paq.push(['trackPageView']);
# 	_paq.push(['enableLinkTracking']);
# 	(function() {
# 		var u="//piwik.diw.de/piwik/";
# 		_paq.push(['setTrackerUrl', u+'piwik.php']);
# 		_paq.push(['setSiteId', 23]);
# 		var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
# 		g.type='text/javascript'; g.async=true; g.defer=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
# 	})();
# </script>
# <noscript><p><img alt="" src="//piwik.diw.de/piwik/piwik.php?idsite=23" style="border:0;"/></p></noscript>
# <!-- End Piwik Code -->
# </body>
# </html>

# %%
# Take contents of infobox
# Make it flexible, so we capture variouse types of fields
infobox = soup.find("div", class_ = "info-box")

# Save in dictionary
event_dict = {}
for child in infobox.children:
    ##### Skip if whitespace
    ### Note: strip() removed leading and trailing whitespaces
    # The advantage over e.g. child == "" here is that strip()
    # also capture other white spaces (e.g. tabs, line breaks)
    ### Further note: If child is not a string, the following if condition
    # yields a TypeError. Catching the exception here helps.
    try:
        if child.strip() == "":
            # continue loop with next iteration
            pass
    # Do something else if TypeError
    except TypeError:
        # The element now should have a "class" attribute
        
        ### Special case for the "location" element: Take the children of it
        if child["class"][0] == "location":
            # Take all span elements with address info
            spans = child.find("div", class_ = "address").find_all("span")
            # Loop and save
            for span in spans:
                # Create variable name using class name
                varname = "address_" + span["class"][0]
                # Get value
                # Note: This removes multiple whitespaces and replaces them
                # by a single space
                value = " ".join(span.text.strip().split())
                # Save
                event_dict[varname] = value
        # Take the class and check if it is called "label". If so, skip it
        elif child["class"][0] == "label":
            pass
        # Else, take the class as variable name and take the contents
        # as values
        else:
            varname = child["class"][0]
            value = " ".join(child.text.strip().split())
            event_dict[varname] = value
# Look at the event_dict
event_dict
# Out:
# {'date': 'June 17, 2019',
#  'time': 'Time 16:00–17:15',
#  'address_name': 'Humboldt-Universität zu Berlin',
#  'address_address': 'Spandauer Str. 1, Room 22',
#  'address_zip': '10178',
#  'address_place': 'Berlin'}

# %%
# Next, take contents of main page
cont = soup.find("div", class_ = "content") \
    .find("div", class_ = "description")
# Loop through children
for child in cont.children:
    ##### Skip if whitespace
    ### Note: strip() removed leading and trailing whitespaces
    # The advantage over e.g. child == "" here is that strip()
    # also capture other white spaces (e.g. tabs, line breaks)
    ### Further note: If child is not a string, the following if condition
    # yields a TypeError. Catching the exception here helps.
    try:
        if child.strip() == "":
            # continue loop with next iteration
            pass
    # Do something else if TypeError
    except TypeError:
        # The element now should have a "class" attribute
        
        ### Special case for the "location" element: Take the children of it
        if child["class"][0] == "label":
            pass
        # Else, take the class as variable name and take the contents
        # as values
        else:
            varname = child["class"][0]
            value = " ".join(child.text.strip().split())
            event_dict[varname] = value
            # Check if the element contains links, if so save
            links = child.find_all("a")
            # Loop through links and save
            for link in links:
                # Take content in lowercase and with underscore as variable name
                varname = "_".join(link.text.strip().lower().split())
                # URL
                url = link["href"]
                # Save
                event_dict[varname] = url

# %%
# Look at the event_dict
event_dict
# Out:
# {'date': 'June 17, 2019',
#  'time': 'Time 16:00–17:15',
#  'address_name': 'Humboldt-Universität zu Berlin',
#  'address_address': 'Spandauer Str. 1, Room 22',
#  'address_zip': '10178',
#  'address_place': 'Berlin',
#  'headline--desktop': 'Sandra McNally (University of Surrey and LSE)',
#  'teaser': 'Topic:Closing the Gap Between Vocational and General Education? - Evidence from University Technical Colleges in England',
#  'description__bodytext': 'Go to speaker website.',
#  'speaker_website': 'https://www.surrey.ac.uk/people/sandra-mcnally'}

# %%
### Now do this for all URLs
# Save in large dictionary
resdict = {}
for url in df["url"].values:
    
    # Message to let us know where we are
    print("Loading %s" % url)

    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    
    # Take contents of infobox
    # Make it flexible, so we capture variouse types of fields
    infobox = soup.find("div", class_ = "info-box")

    # Save in dictionary
    event_dict = {}
    for child in infobox.children:
        ##### Skip if whitespace
        ### Note: strip() removed leading and trailing whitespaces
        # The advantage over e.g. child == "" here is that strip()
        # also capture other white spaces (e.g. tabs, line breaks)
        ### Further note: If child is not a string, the following if condition
        # yields a TypeError. Catching the exception here helps.
        try:
            if child.strip() == "":
                # continue loop with next iteration
                pass
        # Do something else if TypeError
        except TypeError:
            # The element now should have a "class" attribute

            ### Special case for the "location" element: Take the children of it
            if child["class"][0] == "location":
                # Take all span elements with address info
                spans = child.find("div", class_ = "address").find_all("span")
                # Loop and save
                for span in spans:
                    # Create variable name using class name
                    varname = "address_" + span["class"][0]
                    # Get value
                    # Note: This removes multiple whitespaces and replaces them
                    # by a single space
                    value = " ".join(span.text.strip().split())
                    # Save
                    event_dict[varname] = value
            # Take the class and check if it is called "label". If so, skip it
            elif child["class"][0] == "label":
                pass
            # Else, take the class as variable name and take the contents
            # as values
            else:
                varname = child["class"][0]
                value = " ".join(child.text.strip().split())
                event_dict[varname] = value
    # Next, take contents of main page
    cont = soup.find("div", class_ = "content") \
        .find("div", class_ = "description")
    # Loop through children
    for child in cont.children:
        ##### Skip if whitespace
        ### Note: strip() removed leading and trailing whitespaces
        # The advantage over e.g. child == "" here is that strip()
        # also capture other white spaces (e.g. tabs, line breaks)
        ### Further note: If child is not a string, the following if condition
        # yields a TypeError. Catching the exception here helps.
        try:
            if child.strip() == "":
                # continue loop with next iteration
                pass
        # Do something else if TypeError
        except TypeError:
            # The element now should have a "class" attribute

            ### Special case for the "location" element: Take the children of it
            if child["class"][0] == "label":
                pass
            # Else, take the class as variable name and take the contents
            # as values
            else:
                varname = child["class"][0]
                value = " ".join(child.text.strip().split())
                event_dict[varname] = value
                # Check if the element contains links, if so save
                links = child.find_all("a")
                # Loop through links and save
                for link in links:
                    # Take content in lowercase and with underscore as variable name
                    varname = "link_" + "_".join(link.text.strip().lower().split())
                    # URL
                    linkurl = link["href"]
                    # Save
                    event_dict[varname] = linkurl
                    
    # Save in resdict and use url as index (we use this later to merge to
    # previously created df)
    resdict[url] = event_dict
# Create DataFrame
df_details = pd.DataFrame(resdict).T
# Look at it
df_details
# Out:
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/tba-27/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/ricardo-alonso-london-school-of-economics-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/martin-sefton-university-of-nottingham/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/bccp-conference-and-policy-forum-2019/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/matthias-lang-lmu-munich-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/julian-harke-and-kevin-tran/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/felix-holzmeister-university-of-innsbruck/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/bettina-siflinger-tilburg-university/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/ariel-rubinstein-tel-aviv-university-2/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/antonio-rosato-ut-sydney-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/12th-berlin-io-day/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/joergen-weibull-stockholm-school-of-economics-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/tom-chang-university-of-southern-california/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/jidong-zhou-yale-som-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/tim-cason-purdue-university/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/paul-heidhues-dice/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/paul-heidhues-duesseldorf-institute-for-competition-economics-dice/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/andrew-rhodes-tse-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/ala-avoyan-indiana-university/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/florian-scheuer-university-of-zurich-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/yair-antlertel-aviv-university-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/andreas-lange-university-of-hamburg/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/marco-faravelli-university-of-queensland/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/alexandre-de-cornieretse-1/
# Loading http://www.bccp-berlin.de/events/all-events/events-detail/christian-hofmann-lmu/
#                                                                         address_address  \
# http://www.bccp-berlin.de/events/all-events/eve...            Spandauer Str. 1, Room 22
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...  Reichpietschufer 50, Room B 002/003
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room A300
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...            Spandauer Str. 1, Room 22
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...              Straße des 17. Juni 135
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...  Reichpietschufer 50, Room B 002/003
# http://www.bccp-berlin.de/events/all-events/eve...  Ernst-Reuter-Platz 1, Room BH-N 243
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...   Reichpietschufer 50, Room D118/119
# http://www.bccp-berlin.de/events/all-events/eve...  Ernst-Reuter-Platz 1, Room BH-N 243
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...  Ernst-Reuter-Platz 1, Room BH-N 243
# http://www.bccp-berlin.de/events/all-events/eve...  Ernst-Reuter-Platz 1, Room BH-N 243
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
# http://www.bccp-berlin.de/events/all-events/eve...       Reichpietschufer 50, Room B001
#
#                                                                       address_name  \
# http://www.bccp-berlin.de/events/all-events/eve...  Humboldt-Universität zu Berlin
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             NaN
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...  Humboldt-Universität zu Berlin
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...   Technische Universität Berlin
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...   Technische Universität Berlin
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...   Technische Universität Berlin
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...   Technische Universität Berlin
# http://www.bccp-berlin.de/events/all-events/eve...   Technische Universität Berlin
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
# http://www.bccp-berlin.de/events/all-events/eve...                             WZB
#
#                                                    address_place address_zip  \
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10178
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...           NaN         NaN
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10178
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10587
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10587
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10587
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10587
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
# http://www.bccp-berlin.de/events/all-events/eve...        Berlin       10785
#
#                                                             b-events__multi-performance  \
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...  Dates June 24, 2019 - June 26, 2019
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                  NaN
#
#                                                    b-events__multi-performance__label  \
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                       Date Details
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                NaN
#
#                                                                   date  \
# http://www.bccp-berlin.de/events/all-events/eve...       June 17, 2019
# http://www.bccp-berlin.de/events/all-events/eve...       June 17, 2019
# http://www.bccp-berlin.de/events/all-events/eve...       June 20, 2019
# http://www.bccp-berlin.de/events/all-events/eve...       June 21, 2019
# http://www.bccp-berlin.de/events/all-events/eve...       June 24, 2019
# http://www.bccp-berlin.de/events/all-events/eve...                 NaN
# http://www.bccp-berlin.de/events/all-events/eve...       June 27, 2019
# http://www.bccp-berlin.de/events/all-events/eve...       July 01, 2019
# http://www.bccp-berlin.de/events/all-events/eve...       July 01, 2019
# http://www.bccp-berlin.de/events/all-events/eve...       July 08, 2019
# http://www.bccp-berlin.de/events/all-events/eve...  September 20, 2019
# http://www.bccp-berlin.de/events/all-events/eve...    October 21, 2019
# http://www.bccp-berlin.de/events/all-events/eve...    October 24, 2019
# http://www.bccp-berlin.de/events/all-events/eve...    October 28, 2019
# http://www.bccp-berlin.de/events/all-events/eve...    October 31, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   November 07, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   November 07, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   November 11, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   November 14, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   November 25, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   December 02, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   December 05, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   December 12, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   December 16, 2019
# http://www.bccp-berlin.de/events/all-events/eve...   February 03, 2020
#
#                                                                                 description__bodytext  \
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...  The tremendous growth of digital transactions ...
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...  This short course by BCCP Doctoral Students Ju...
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
# http://www.bccp-berlin.de/events/all-events/eve...                             Go to speaker website.
#
#                                                                                     headline--desktop  \
# http://www.bccp-berlin.de/events/all-events/eve...      Sandra McNally (University of Surrey and LSE)
# http://www.bccp-berlin.de/events/all-events/eve...        Ricardo Alonso (London School of Economics)
# http://www.bccp-berlin.de/events/all-events/eve...           Martin Sefton (University of Nottingham)
# http://www.bccp-berlin.de/events/all-events/eve...              BCCP Conference and Policy Forum 2019
# http://www.bccp-berlin.de/events/all-events/eve...                         Matthias Lang (LMU Munich)
# http://www.bccp-berlin.de/events/all-events/eve...  DIW Graduate Center/BCCP Short Course on Web S...
# http://www.bccp-berlin.de/events/all-events/eve...        Felix Holzmeister (University of Innsbruck)
# http://www.bccp-berlin.de/events/all-events/eve...             Bettina Siflinger (Tilburg University)
# http://www.bccp-berlin.de/events/all-events/eve...             Ariel Rubinstein (Tel Aviv University)
# http://www.bccp-berlin.de/events/all-events/eve...                         Antonio Rosato (UT Sydney)
# http://www.bccp-berlin.de/events/all-events/eve...                                 12th Berlin IO Day
# http://www.bccp-berlin.de/events/all-events/eve...     Jörgen Weibull (Stockholm School of Economics)
# http://www.bccp-berlin.de/events/all-events/eve...      Tom Chang (University of Southern California)
# http://www.bccp-berlin.de/events/all-events/eve...                                 Jidong Zhou (Yale)
# http://www.bccp-berlin.de/events/all-events/eve...                      Tim Cason (Purdue University)
# http://www.bccp-berlin.de/events/all-events/eve...                               Paul Heidhues (DICE)
# http://www.bccp-berlin.de/events/all-events/eve...  Paul Heidhues (Düsseldorf Institute for Compet...
# http://www.bccp-berlin.de/events/all-events/eve...                                Andrew Rhodes (TSE)
# http://www.bccp-berlin.de/events/all-events/eve...                    Ala Avoyan (Indiana University)
# http://www.bccp-berlin.de/events/all-events/eve...             Florian Scheuer (University of Zurich)
# http://www.bccp-berlin.de/events/all-events/eve...                  Yair Antler (Tel Aviv University)
# http://www.bccp-berlin.de/events/all-events/eve...              Andreas Lange (University of Hamburg)
# http://www.bccp-berlin.de/events/all-events/eve...         Marco Faravelli (University of Queensland)
# http://www.bccp-berlin.de/events/all-events/eve...                        Alexandre de Cornière (TSE)
# http://www.bccp-berlin.de/events/all-events/eve...                            Christian Hofmann (LMU)
#
#                                                                         link_amelia_fletcher  \
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...  https://people.uea.ac.uk/amelia_fletcher
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                       NaN
#
#                                                     ...  \
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
# http://www.bccp-berlin.de/events/all-events/eve...  ...
#
#                                                                           link_marit_hansen  \
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...  https://www.hansen-kronshagen.de/marit/
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                      NaN
#
#                                                                     link_matthew_gentzkow  \
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...  https://gentzkow.people.stanford.edu/
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                    NaN
#
#                                                                                      link_paul_nemitz  \
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...  https://www.coleurope.eu/whoswho/person/paul.n...
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
#
#                                                                                  link_speaker_website  \
# http://www.bccp-berlin.de/events/all-events/eve...     https://www.surrey.ac.uk/people/sandra-mcnally
# http://www.bccp-berlin.de/events/all-events/eve...  https://sites.google.com/site/ricardoalonsoweb...
# http://www.bccp-berlin.de/events/all-events/eve...  https://www.nottingham.ac.uk/economics/people/...
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                       https://lang.userweb.mwn.de/
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                       https://www.holzmeister.biz/
# http://www.bccp-berlin.de/events/all-events/eve...    https://sites.google.com/site/bettinasiflinger/
# http://www.bccp-berlin.de/events/all-events/eve...  https://en-social-sciences.tau.ac.il/profile/r...
# http://www.bccp-berlin.de/events/all-events/eve...  https://sites.google.com/site/rosatoeconomics/...
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...      https://sites.google.com/site/joergenweibull/
# http://www.bccp-berlin.de/events/all-events/eve...                          https://www.tomychang.com
# http://www.bccp-berlin.de/events/all-events/eve...        https://sites.google.com/site/jidongzhou77/
# http://www.bccp-berlin.de/events/all-events/eve...  https://krannert.purdue.edu/faculty/cason/home...
# http://www.bccp-berlin.de/events/all-events/eve...  http://www.dice.hhu.de/diceteam/professorinnen...
# http://www.bccp-berlin.de/events/all-events/eve...  http://www.dice.hhu.de/en/diceteam/professors/...
# http://www.bccp-berlin.de/events/all-events/eve...  https://sites.google.com/site/andrewrhodesecon...
# http://www.bccp-berlin.de/events/all-events/eve...                         https://www.alaavoyan.com/
# http://www.bccp-berlin.de/events/all-events/eve...  https://www.econ.uzh.ch/en/people/faculty/sche...
# http://www.bccp-berlin.de/events/all-events/eve...                     https://yairantler.weebly.com/
# http://www.bccp-berlin.de/events/all-events/eve...  https://www.wiso.uni-hamburg.de/en/fachbereich...
# http://www.bccp-berlin.de/events/all-events/eve...                     http://www.marcofaravelli.com/
# http://www.bccp-berlin.de/events/all-events/eve...         https://sites.google.com/site/adecorniere/
# http://www.bccp-berlin.de/events/all-events/eve...  https://www.iuc.bwl.uni-muenchen.de/personen/p...
#
#                                                                                      link_stefan_hunt  \
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...  https://competitionandmarkets.blog.gov.uk/auth...
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
#
#                                                                                  link_tomaso_duso  \
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...  https://sites.google.com/site/tomasoduso/home
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                            NaN
#
#                                                                          link_twitter_feed:_#bccpconf  \
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...  https://twitter.com/hashtag/bccpconf?f=tweets&...
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
#
#                                                                                  performance__details  \
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...  June 24, 2019 Open Details Time 09:30–12:30 Lo...
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
#
#                                                                                                teaser  \
# http://www.bccp-berlin.de/events/all-events/eve...  Topic:Closing the Gap Between Vocational and G...
# http://www.bccp-berlin.de/events/all-events/eve...                   Topic:Tampering with Information
# http://www.bccp-berlin.de/events/all-events/eve...  Topic:Communication with partially verifiable ...
# http://www.bccp-berlin.de/events/all-events/eve...  Topic:Regulatory Challenges in Digital Markets...
# http://www.bccp-berlin.de/events/all-events/eve...           Topic:Bilateral Trade with Justification
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...         Topic:Delegated decision making in finance
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                                NaN
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
# http://www.bccp-berlin.de/events/all-events/eve...                                          Topic:TBA
#
#                                                                 time
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:00–17:15
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 09:50–16:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...               NaN
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:00–17:15
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 09:00–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 16:45–18:00
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
# http://www.bccp-berlin.de/events/all-events/eve...  Time 17:15–18:30
#
# [25 rows x 28 columns]

# %%
### Merge back to df
# Use "url" for df and index for df_details
# Note: The suffixes attribute adds a "_details" to all variables
# from df_details whose name already exists in df (e.g. date)
df = df.merge(df_details, left_on = "url", right_index = True, \
    validate = "1:1", how = "left", suffixes = ("", "_details"))

# Look at it
df
# Out:
#                              date                         event_series  \
# 0                   June 17, 2019         Berlin Applied Micro Seminar
# 1                   June 17, 2019          Berlin Micro Theory Seminar
# 2                   June 20, 2019  Berlin Behavioral Economics Seminar
# 3                   June 21, 2019                      BCCP Conference
# 4                   June 24, 2019          Berlin Micro Theory Seminar
# 5   June 24, 2019 - June 26, 2019                         Other events
# 6                   June 27, 2019  Berlin Behavioral Economics Seminar
# 7                   July 01, 2019         Berlin Applied Micro Seminar
# 8                   July 01, 2019          Berlin Micro Theory Seminar
# 9                   July 08, 2019          Berlin Micro Theory Seminar
# 10             September 20, 2019                        Berlin IO Day
# 11               October 21, 2019          Berlin Micro Theory Seminar
# 12               October 24, 2019  Berlin Behavioral Economics Seminar
# 13               October 28, 2019          Berlin Micro Theory Seminar
# 14               October 31, 2019  Berlin Behavioral Economics Seminar
# 15              November 07, 2019          Berlin Micro Theory Seminar
# 16              November 07, 2019  Berlin Behavioral Economics Seminar
# 17              November 11, 2019          Berlin Micro Theory Seminar
# 18              November 14, 2019  Berlin Behavioral Economics Seminar
# 19              November 25, 2019          Berlin Micro Theory Seminar
# 20              December 02, 2019          Berlin Micro Theory Seminar
# 21              December 05, 2019  Berlin Behavioral Economics Seminar
# 22              December 12, 2019  Berlin Behavioral Economics Seminar
# 23              December 16, 2019          Berlin Micro Theory Seminar
# 24              February 03, 2020          Berlin Micro Theory Seminar
#
#              event_type                           loc_address  \
# 0               Seminar             Spandauer Str. 1, Room 22
# 1               Seminar        Reichpietschufer 50, Room B001
# 2               Seminar   Reichpietschufer 50, Room B 002/003
# 3   Conference & Events        Reichpietschufer 50, Room A300
# 4               Seminar        Reichpietschufer 50, Room B001
# 5   Conference & Events  Mohrenstr. 58, Room Anna J. Schwartz
# 6               Seminar        Reichpietschufer 50, Room B001
# 7               Seminar             Spandauer Str. 1, Room 22
# 8               Seminar        Reichpietschufer 50, Room B001
# 9               Seminar        Reichpietschufer 50, Room B001
# 10  Conference & Events               Straße des 17. Juni 135
# 11              Seminar        Reichpietschufer 50, Room B001
# 12              Seminar        Reichpietschufer 50, Room B001
# 13              Seminar   Reichpietschufer 50, Room B 002/003
# 14              Seminar   Ernst-Reuter-Platz 1, Room BH-N 243
# 15              Seminar        Reichpietschufer 50, Room B001
# 16              Seminar        Reichpietschufer 50, Room B001
# 17              Seminar    Reichpietschufer 50, Room D118/119
# 18              Seminar   Ernst-Reuter-Platz 1, Room BH-N 243
# 19              Seminar        Reichpietschufer 50, Room B001
# 20              Seminar        Reichpietschufer 50, Room B001
# 21              Seminar   Ernst-Reuter-Platz 1, Room BH-N 243
# 22              Seminar   Ernst-Reuter-Platz 1, Room BH-N 243
# 23              Seminar        Reichpietschufer 50, Room B001
# 24              Seminar        Reichpietschufer 50, Room B001
#
#                           loc_name loc_place loc_zip         time  \
# 0   Humboldt-Universität zu Berlin    Berlin   10178  16:00–17:15
# 1                              WZB    Berlin   10785  17:15–18:30
# 2                              WZB    Berlin   10785  16:45–18:00
# 3                              WZB    Berlin   10785  09:50–16:30
# 4                              WZB    Berlin   10785  17:15–18:30
# 5                              DIW    Berlin   10117  09:30–12:30
# 6                              WZB    Berlin   10785  16:45–18:00
# 7   Humboldt-Universität zu Berlin    Berlin   10178  16:00–17:15
# 8                              WZB    Berlin   10785  17:15–18:30
# 9                              WZB    Berlin   10785  17:15–18:30
# 10   Technische Universität Berlin                    09:00–18:00
# 11                             WZB    Berlin   10785  17:15–18:30
# 12                             WZB    Berlin   10785  16:45–18:00
# 13                             WZB    Berlin   10785  17:15–18:30
# 14   Technische Universität Berlin    Berlin   10587  16:45–18:00
# 15                             WZB    Berlin   10785  16:45–18:00
# 16                             WZB    Berlin   10785  16:45–18:00
# 17                             WZB    Berlin   10785  17:15–18:30
# 18   Technische Universität Berlin    Berlin   10587  16:45–18:00
# 19                             WZB    Berlin   10785  17:15–18:30
# 20                             WZB    Berlin   10785  17:15–18:30
# 21   Technische Universität Berlin    Berlin   10587  16:45–18:00
# 22   Technische Universität Berlin    Berlin   10587  16:45–18:00
# 23                             WZB    Berlin   10785  17:15–18:30
# 24                             WZB    Berlin   10785  17:15–18:30
#
#                                                 title  \
# 0       Sandra McNally (University of Surrey and LSE)
# 1         Ricardo Alonso (London School of Economics)
# 2            Martin Sefton (University of Nottingham)
# 3               BCCP Conference and Policy Forum 2019
# 4                          Matthias Lang (LMU Munich)
# 5   DIW Graduate Center/BCCP Short Course on Web S...
# 6         Felix Holzmeister (University of Innsbruck)
# 7              Bettina Siflinger (Tilburg University)
# 8              Ariel Rubinstein (Tel Aviv University)
# 9                          Antonio Rosato (UT Sydney)
# 10                                 12th Berlin IO Day
# 11     Jörgen Weibull (Stockholm School of Economics)
# 12      Tom Chang (University of Southern California)
# 13                                 Jidong Zhou (Yale)
# 14                      Tim Cason (Purdue University)
# 15                               Paul Heidhues (DICE)
# 16  Paul Heidhues (Düsseldorf Institute for Compet...
# 17                                Andrew Rhodes (TSE)
# 18                    Ala Avoyan (Indiana University)
# 19             Florian Scheuer (University of Zurich)
# 20                  Yair Antler (Tel Aviv University)
# 21              Andreas Lange (University of Hamburg)
# 22         Marco Faravelli (University of Queensland)
# 23                        Alexandre de Cornière (TSE)
# 24                            Christian Hofmann (LMU)
#
#                                                 topic  ...  \
# 0   Closing the Gap Between Vocational and General...  ...
# 1                          Tampering with Information  ...
# 2   Communication with partially verifiable inform...  ...
# 3   Regulatory Challenges in Digital Markets: the ...  ...
# 4                  Bilateral Trade with Justification  ...
# 5                                                      ...
# 6                Delegated decision making in finance  ...
# 7                                                 TBA  ...
# 8                                                 TBA  ...
# 9                                                 TBA  ...
# 10                                                     ...
# 11                                                TBA  ...
# 12                                                TBA  ...
# 13                                                TBA  ...
# 14                                                TBA  ...
# 15                                                TBA  ...
# 16                                                TBA  ...
# 17                                                TBA  ...
# 18                                                TBA  ...
# 19                                                TBA  ...
# 20                                                TBA  ...
# 21                                                TBA  ...
# 22                                                TBA  ...
# 23                                                TBA  ...
# 24                                                TBA  ...
#
#                           link_marit_hansen  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3   https://www.hansen-kronshagen.de/marit/
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
#
#                     link_matthew_gentzkow  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3   https://gentzkow.people.stanford.edu/
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
#
#                                      link_paul_nemitz  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://www.coleurope.eu/whoswho/person/paul.n...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                  link_speaker_website  \
# 0      https://www.surrey.ac.uk/people/sandra-mcnally
# 1   https://sites.google.com/site/ricardoalonsoweb...
# 2   https://www.nottingham.ac.uk/economics/people/...
# 3                                                 NaN
# 4                        https://lang.userweb.mwn.de/
# 5                                                 NaN
# 6                        https://www.holzmeister.biz/
# 7     https://sites.google.com/site/bettinasiflinger/
# 8   https://en-social-sciences.tau.ac.il/profile/r...
# 9   https://sites.google.com/site/rosatoeconomics/...
# 10                                                NaN
# 11      https://sites.google.com/site/joergenweibull/
# 12                          https://www.tomychang.com
# 13        https://sites.google.com/site/jidongzhou77/
# 14  https://krannert.purdue.edu/faculty/cason/home...
# 15  http://www.dice.hhu.de/diceteam/professorinnen...
# 16  http://www.dice.hhu.de/en/diceteam/professors/...
# 17  https://sites.google.com/site/andrewrhodesecon...
# 18                         https://www.alaavoyan.com/
# 19  https://www.econ.uzh.ch/en/people/faculty/sche...
# 20                     https://yairantler.weebly.com/
# 21  https://www.wiso.uni-hamburg.de/en/fachbereich...
# 22                     http://www.marcofaravelli.com/
# 23         https://sites.google.com/site/adecorniere/
# 24  https://www.iuc.bwl.uni-muenchen.de/personen/p...
#
#                                      link_stefan_hunt  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://competitionandmarkets.blog.gov.uk/auth...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                  link_tomaso_duso  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3   https://sites.google.com/site/tomasoduso/home
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
#
#                          link_twitter_feed:_#bccpconf  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://twitter.com/hashtag/bccpconf?f=tweets&...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                  performance__details  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   June 24, 2019 Open Details Time 09:30–12:30 Lo...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                                teaser      time_details
# 0   Topic:Closing the Gap Between Vocational and G...  Time 16:00–17:15
# 1                    Topic:Tampering with Information  Time 17:15–18:30
# 2   Topic:Communication with partially verifiable ...  Time 16:45–18:00
# 3   Topic:Regulatory Challenges in Digital Markets...  Time 09:50–16:30
# 4            Topic:Bilateral Trade with Justification  Time 17:15–18:30
# 5                                                 NaN               NaN
# 6          Topic:Delegated decision making in finance  Time 16:45–18:00
# 7                                           Topic:TBA  Time 16:00–17:15
# 8                                           Topic:TBA  Time 17:15–18:30
# 9                                           Topic:TBA  Time 17:15–18:30
# 10                                                NaN  Time 09:00–18:00
# 11                                          Topic:TBA  Time 17:15–18:30
# 12                                          Topic:TBA  Time 16:45–18:00
# 13                                          Topic:TBA  Time 17:15–18:30
# 14                                          Topic:TBA  Time 16:45–18:00
# 15                                          Topic:TBA  Time 16:45–18:00
# 16                                          Topic:TBA  Time 16:45–18:00
# 17                                          Topic:TBA  Time 17:15–18:30
# 18                                          Topic:TBA  Time 16:45–18:00
# 19                                          Topic:TBA  Time 17:15–18:30
# 20                                          Topic:TBA  Time 17:15–18:30
# 21                                          Topic:TBA  Time 16:45–18:00
# 22                                          Topic:TBA  Time 16:45–18:00
# 23                                          Topic:TBA  Time 17:15–18:30
# 24                                          Topic:TBA  Time 17:15–18:30
#
# [25 rows x 39 columns]

# %%
###############################################################################
################################# 6. SAVE CSV #################################
###############################################################################

# Save csv
df.to_csv(savefile, sep = ";", encoding = "utf-8-sig")
